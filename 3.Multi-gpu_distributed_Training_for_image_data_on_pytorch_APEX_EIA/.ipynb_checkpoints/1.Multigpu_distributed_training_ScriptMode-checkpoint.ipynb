# %% [markdown]
# # 1.Multigpu Distributed Training-ScriptMode
# ---
#
# 본 모듈에서는 Amzaon SageMaker API을 효과적으로 이용하기 위해 multigpu-distributed 학습을 위한 PyTorch 프레임워크 자체 구현만으로 모델 훈련을 수행해 봅니다.

# %% [markdown]
# ## 1. Sagemaker notebook 설명
# <p>Sagemaker notebook은 완전 관리형 서비스로 컨테이너 기반으로 구성되어 있습니다. 사용자가 직접 컨테이너를 볼 수 없지만, 내부적으로는 아래와 같은 원리로 동작합니다. </p>
# <p><img src="./imgs/fig00.png" width="800", height="80"></p>
#
# - **S3 (Simple Storage Serivce)** : Object Storage로서 학습할 데이터 파일과 학습 결과인 model, checkpoint, tensorboard를 위한 event 파일, 로그 정보 등을 저장하는데 사용합니다.
# - **SageMaker Notebook** : 학습을 위한 스크립트 작성과 디버깅, 그리고 실제 학습을 수행하기 위한 Python을 개발하기 위한 환경을 제공합니다.
# - **Amazon Elastic Container Registry(ECR)** :  Docker 컨테이너 이미지를 손쉽게 저장, 관리 및 배포할 수 있게 해주는 완전관리형 Docker 컨테이너 레지스트리입니다. Sagemaker는 기본적인 컨테이너를 제공하기 때문에 별도 ECR에 컨테이너 이미지를 등록할 필요는 없습니다. 하지만, 별도의 학습 및 배포 환경이 필요한 경우 custom 컨테이너 이미지를 만들어서 ECR에 등록한 후 이 환경을 활용할 수 있습니다.
#
# <p>학습과 추론을 하는 hosting 서비스는 각각 다른 컨테이너 환경에서 수행할 수 있으며, 쉽게 다량으로 컨테이너 환경을 확장할 수 있으므로 다량의 학습과 hosting이 동시에 가능합니다.
# </p>

# %%
import sys

# %%
# !{sys.executable} -m pip install split-folders tqdm
# !{sys.executable} -m pip install 'sagemaker[local]' --upgrade
# Out:
# Requirement already satisfied: split-folders in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (0.3.1)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages (4.44.1)

# %% [markdown]
# ## 2. 환경 설정
#
# <p>Sagemaker 학습에 필요한 기본적인 package를 import 합니다. </p>
# <p>boto3는 HTTP API 호출을 숨기는 편한 추상화 모델을 가지고 있고, Amazon EC2 인스턴스 및 S3 버켓과 같은 AWS 리소스와 동작하는 파이선 클래스를 제공합니다. </p>
# <p>sagemaker python sdk는 Amazon SageMaker에서 기계 학습 모델을 교육 및 배포하기 위한 오픈 소스 라이브러리입니다.</p>

# %%
import joblib
import matplotlib.pyplot as plt
import sagemaker
import split_folders

import datetime
import glob
import os
import time
import warnings

import boto3
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torchvision

from PIL import Image
from torch.utils.data import Dataset
from torchvision import datasets, transforms

from sagemaker import get_execution_role
from sagemaker.pytorch import PyTorch

warnings.filterwarnings('ignore')
# %config InlineBackend.figure_format = 'retina'

# %%
sess = boto3.Session()
sagemaker_session = sagemaker.Session()
sm = sess.client('sagemaker')
role = get_execution_role()

# %% [markdown]
# ## 3. S3의 저장 데이터 위치 가져오기
# <p> 데이터를 정하기 위한 S3의 bucket 위치는 아래 data_bucket 이름으로 생성하며, 기본적으로 SageMaker에서 학습한 모델과 로그 정보를 남기는 위치는 자동으로 생성되는 bucket 이름으로 저장됩니다. </p>

# %%
# create a s3 bucket to hold data, note that your account might already created a bucket with the same name
account_id = sess.client('sts').get_caller_identity()["Account"]
job_bucket = 'sagemaker-experiments-{}-{}'.format(sess.region_name, account_id)
data_bucket = 'sagemaker-{}-{}'.format(sess.region_name, account_id)
try:
    if sess.region_name == "us-east-1":
        sess.client('s3').create_bucket(Bucket=data_bucket)
    else:
        sess.client('s3').create_bucket(Bucket=data_bucket, 
                                        CreateBucketConfiguration={'LocationConstraint': sess.region_name})
except Exception as e:
    print(e)
# Out:
# An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %% [markdown]
# ## 4. Dataset 소개 및 split 후 S3 upload하기
# <p>이번 학습에 사용할 이미지 데이터는 <strong><a href="https://www.robots.ox.ac.uk/~vgg/data/pets/" target="_blank" class ='btn-default'>Oxford-IIIT Pet Dataset</a></strong> 입니다. Oxford-IIIT Pet Dataset은 <strong>37</strong>개 다른 종의 개와 고양이 이미지를 각각 200장 씩 제공하고 있으며, Ground Truth 또한 Classification, Object Detection, Segmentation와 관련된 모든 정보가 있으나, 이번 학습에서는 37개 class에 대해 일부 이미지로 Classification 문제를 해결하기 위해 학습을 진행할 예정입니다.</p>
# <p><img src="./imgs/pet_annotations.jpg" width="700", height="70"></p>
# <p>이미지 파일을 학습하기 위해 SageMaker Notebook 환경으로 upload를 합니다. 폴더 구조는 아래와 같은 형태로 구성되어야 합니다. </p>
# <pre>
# <div style='line-height:80%'>
#     image_path/class1/Aimage_1<br>
#                       Aimage_2<br>
#                        ...<br>
#                       Aimage_N<br>
#     image_path/class2/Bimage_1<br>
#                       Bimage_2<br>
#                        ...<br>
#                       Bimage_M<br>
# </div>
# </pre>

# %% [markdown]
# <p>SageMaker 학습을 위해 train/val로 분리한 폴더를 S3내 이전에 지정한 data_bucket 내 prefix 하위 폴더로 upload합니다. </p>

# %%
split_folders.ratio('data', output="dataset", seed=1337, ratio=(.8, .1, .1)) # default values
s3_data_path = 's3://{}/{}'.format(data_bucket, 'oxford_pet_dataset')
# !aws s3 cp ./dataset $s3_data_path --recursive
# Out:
# Copying files: 7388 files [00:07, 983.71 files/s]
# upload: dataset/test/Abyssinian/Abyssinian_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_123.jpg
# upload: dataset/test/Abyssinian/Abyssinian_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_146.jpg
# upload: dataset/test/Abyssinian/Abyssinian_190.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_190.jpg
# upload: dataset/test/Abyssinian/Abyssinian_173.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_173.jpg
# upload: dataset/test/Abyssinian/Abyssinian_21.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_21.jpg
# upload: dataset/test/Abyssinian/Abyssinian_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_19.jpg
# upload: dataset/test/Abyssinian/Abyssinian_196.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_196.jpg
# upload: dataset/test/Abyssinian/Abyssinian_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_65.jpg
# upload: dataset/test/Abyssinian/Abyssinian_2.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_2.jpg
# upload: dataset/test/Abyssinian/Abyssinian_18.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_18.jpg
# upload: dataset/test/Abyssinian/Abyssinian_48.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_48.jpg
# upload: dataset/test/Abyssinian/Abyssinian_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_137.jpg
# upload: dataset/test/Abyssinian/Abyssinian_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_82.jpg
# upload: dataset/test/Abyssinian/Abyssinian_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_8.jpg
# upload: dataset/test/Abyssinian/Abyssinian_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_96.jpg
# upload: dataset/test/Abyssinian/Abyssinian_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_70.jpg
# upload: dataset/test/Abyssinian/Abyssinian_34.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_34.jpg
# upload: dataset/test/Abyssinian/Abyssinian_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_50.jpg
# upload: dataset/test/Abyssinian/Abyssinian_60.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_60.jpg
# upload: dataset/test/Bengal/Bengal_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_123.jpg
# upload: dataset/test/Abyssinian/Abyssinian_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Abyssinian/Abyssinian_88.jpg
# upload: dataset/test/Bengal/Bengal_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_137.jpg
# upload: dataset/test/Bengal/Bengal_190.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_190.jpg
# upload: dataset/test/Bengal/Bengal_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_146.jpg
# upload: dataset/test/Bengal/Bengal_184.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_184.jpg
# upload: dataset/test/Bengal/Bengal_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_183.jpg
# upload: dataset/test/Bengal/Bengal_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_50.jpg
# upload: dataset/test/Bengal/Bengal_198.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_198.jpg
# upload: dataset/test/Bengal/Bengal_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_176.jpg
# upload: dataset/test/Bengal/Bengal_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_61.jpg
# upload: dataset/test/Bengal/Bengal_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_65.jpg
# upload: dataset/test/Bengal/Bengal_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_82.jpg
# upload: dataset/test/Bengal/Bengal_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_17.jpg
# upload: dataset/test/Bengal/Bengal_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_8.jpg
# upload: dataset/test/Bengal/Bengal_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_70.jpg
# upload: dataset/test/Bengal/Bengal_41.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_41.jpg
# upload: dataset/test/Bengal/Bengal_189.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_189.jpg
# upload: dataset/test/Bengal/Bengal_53.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_53.jpg
# upload: dataset/test/Bengal/Bengal_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_88.jpg
# upload: dataset/test/Birman/Birman_182.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_182.jpg
# upload: dataset/test/Birman/Birman_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_176.jpg
# upload: dataset/test/Bengal/Bengal_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bengal/Bengal_96.jpg
# upload: dataset/test/Birman/Birman_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_183.jpg
# upload: dataset/test/Birman/Birman_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_137.jpg
# upload: dataset/test/Birman/Birman_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_146.jpg
# upload: dataset/test/Birman/Birman_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_123.jpg
# upload: dataset/test/Birman/Birman_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_188.jpg
# upload: dataset/test/Birman/Birman_198.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_198.jpg
# upload: dataset/test/Birman/Birman_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_19.jpg
# upload: dataset/test/Birman/Birman_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_61.jpg
# upload: dataset/test/Birman/Birman_41.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_41.jpg
# upload: dataset/test/Birman/Birman_53.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_53.jpg
# upload: dataset/test/Birman/Birman_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_70.jpg
# upload: dataset/test/Birman/Birman_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_8.jpg
# upload: dataset/test/Birman/Birman_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_65.jpg
# upload: dataset/test/Birman/Birman_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_17.jpg
# upload: dataset/test/Birman/Birman_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_50.jpg
# upload: dataset/test/Bombay/Bombay_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay_123.jpg
# upload: dataset/test/Birman/Birman_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_82.jpg
# upload: dataset/test/Bombay/Bombay_181.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay_181.jpg
# upload: dataset/test/Bombay/Bombay_15.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay_15.jpg
# upload: dataset/test/Birman/Birman_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_96.jpg
# upload: dataset/test/Bombay/Bombay_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay_19.jpg
# upload: dataset/test/Bombay/Bombay_189.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay_189.jpg
# upload: dataset/test/Birman/Birman_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Birman/Birman_88.jpg
# upload: dataset/test/Bombay/Bombay_194.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay_194.jpg
# upload: dataset/test/Bombay/Bombay_175.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Bombay/Bombay
jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_143.jpg
# upload: dataset/test/Ragdoll/Ragdoll_180.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_180.jpg
# upload: dataset/test/Persian/Persian_85.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Persian/Persian_85.jpg
# upload: dataset/test/Persian/Persian_67.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Persian/Persian_67.jpg
# upload: dataset/test/Persian/Persian_95.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Persian/Persian_95.jpg
# upload: dataset/test/Ragdoll/Ragdoll_195.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_195.jpg
# upload: dataset/test/Ragdoll/Ragdoll_187.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_187.jpg
# upload: dataset/test/Ragdoll/Ragdoll_154.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_154.jpg
# upload: dataset/test/Ragdoll/Ragdoll_2.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_2.jpg
# upload: dataset/test/Ragdoll/Ragdoll_224.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_224.jpg
# upload: dataset/test/Ragdoll/Ragdoll_44.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_44.jpg
# upload: dataset/test/Ragdoll/Ragdoll_62.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_62.jpg
# upload: dataset/test/Ragdoll/Ragdoll_33.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_33.jpg
# upload: dataset/test/Ragdoll/Ragdoll_58.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_58.jpg
# upload: dataset/test/Ragdoll/Ragdoll_194.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_194.jpg
# upload: dataset/test/Ragdoll/Ragdoll_201.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_201.jpg
# upload: dataset/test/Ragdoll/Ragdoll_7.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_7.jpg
# upload: dataset/test/Ragdoll/Ragdoll_48.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_48.jpg
# upload: dataset/test/Ragdoll/Ragdoll_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_82.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_179.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_179.jpg
# upload: dataset/test/Ragdoll/Ragdoll_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_88.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_127.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_127.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_143.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_143.jpg
# upload: dataset/test/Ragdoll/Ragdoll_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_8.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_185.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_185.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_153.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_153.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_200.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_200.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_208.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_208.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_30.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_30.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_194.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_194.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_199.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_199.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_193.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_193.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_43.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_43.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_47.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_47.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_8.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_59.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_59.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_82.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_63.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_63.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_70.jpg
# upload: dataset/test/Ragdoll/Ragdoll_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Ragdoll/Ragdoll_96.jpg
# upload: dataset/test/Siamese/Siamese_149.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_149.jpg
# upload: dataset/test/Siamese/Siamese_135.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_135.jpg
# upload: dataset/test/Siamese/Siamese_185.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_185.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_88.jpg
# upload: dataset/test/Russian_Blue/Russian_Blue_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Russian_Blue/Russian_Blue_96.jpg
# upload: dataset/test/Siamese/Siamese_159.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_159.jpg
# upload: dataset/test/Siamese/Siamese_200.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_200.jpg
# upload: dataset/test/Siamese/Siamese_201.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_201.jpg
# upload: dataset/test/Siamese/Siamese_35.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_35.jpg
# upload: dataset/test/Siamese/Siamese_208.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_208.jpg
# upload: dataset/test/Siamese/Siamese_193.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_193.jpg
# upload: dataset/test/Siamese/Siamese_206.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_206.jpg
# upload: dataset/test/Siamese/Siamese_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_61.jpg
# upload: dataset/test/Siamese/Siamese_224.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_224.jpg
# upload: dataset/test/Siamese/Siamese_47.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_47.jpg
# upload: dataset/test/Siamese/Siamese_58.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_58.jpg
# upload: dataset/test/Siamese/Siamese_5.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_5.jpg
# upload: dataset/test/Siamese/Siamese_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_82.jpg
# upload: dataset/test/Siamese/Siamese_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_88.jpg
# upload: dataset/test/Sphynx/Sphynx_132.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_132.jpg
# upload: dataset/test/Sphynx/Sphynx_15.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_15.jpg
# upload: dataset/test/Siamese/Siamese_69.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_69.jpg
# upload: dataset/test/Sphynx/Sphynx_186.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_186.jpg
# upload: dataset/test/Siamese/Siamese_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_96.jpg
# upload: dataset/test/Sphynx/Sphynx_199.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_199.jpg
# upload: dataset/test/Siamese/Siamese_79.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Siamese/Siamese_79.jpg
# upload: dataset/test/Sphynx/Sphynx_2.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_2.jpg
# upload: dataset/test/Sphynx/Sphynx_192.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_192.jpg
# upload: dataset/test/Sphynx/Sphynx_160.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_160.jpg
# upload: dataset/test/Sphynx/Sphynx_228.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_228.jpg
# upload: dataset/test/Sphynx/Sphynx_205.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_205.jpg
# upload: dataset/test/Sphynx/Sphynx_203.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_203.jpg
# upload: dataset/test/Sphynx/Sphynx_27.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_27.jpg
# upload: dataset/test/Sphynx/Sphynx_38.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_38.jpg
# upload: dataset/test/Sphynx/Sphynx_54.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_54.jpg
# upload: dataset/test/Sphynx/Sphynx_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_61.jpg
# upload: dataset/test/Sphynx/Sphynx_76.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_76.jpg
# upload: dataset/test/Sphynx/Sphynx_49.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_49.jpg
# upload: dataset/test/Sphynx/Sphynx_40.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_40.jpg
# upload: dataset/test/Sphynx/Sphynx_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_8.jpg
# upload: dataset/test/Sphynx/Sphynx_95.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_95.jpg
# upload: dataset/test/Sphynx/Sphynx_87.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/Sphynx/Sphynx_87.jpg
# upload: dataset/test/american_bulldog/american_bulldog_138.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_138.jpg
# upload: dataset/test/american_bulldog/american_bulldog_148.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_148.jpg
# upload: dataset/test/american_bulldog/american_bulldog_181.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_181.jpg
# upload: dataset/test/american_bulldog/american_bulldog_124.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_124.jpg
# upload: dataset/test/american_bulldog/american_bulldog_194.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_194.jpg
# upload: dataset/test/american_bulldog/american_bulldog_196.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_196.jpg
# upload: dataset/test/american_bulldog/american_bulldog_211.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_211.jpg
# upload: dataset/test/american_bulldog/american_bulldog_201.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_201.jpg
# upload: dataset/test/american_bulldog/american_bulldog_52.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_52.jpg
# upload: dataset/test/american_bulldog/american_bulldog_7.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_7.jpg
# upload: dataset/test/american_bulldog/american_bulldog_40.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_40.jpg
# upload: dataset/test/american_bulldog/american_bulldog_5.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_5.jpg
# upload: dataset/test/american_bulldog/american_bulldog_20.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_20.jpg
# upload: dataset/test/american_bulldog/american_bulldog_60.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_60.jpg
# upload: dataset/test/american_bulldog/american_bulldog_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_188.jpg
# upload: dataset/test/american_bulldog/american_bulldog_81.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_81.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_123.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_137.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_176.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_188.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_17.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_183.jpg
# upload: dataset/test/american_bulldog/american_bulldog_87.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_87.jpg
# upload: dataset/test/american_bulldog/american_bulldog_79.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_79.jpg
# upload: dataset/test/american_bulldog/american_bulldog_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_96.jpg
# upload: dataset/test/american_bulldog/american_bulldog_64.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_bulldog/american_bulldog_64.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_146.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_182.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_182.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_197.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_197.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_6.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_6.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_19.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_4.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_4.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_49.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_49.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_78.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_78.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_88.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_63.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_63.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_51.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_51.jpg
# upload: dataset/test/basset_hound/basset_hound_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_137.jpg
# upload: dataset/test/basset_hound/basset_hound_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_123.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_69.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_69.jpg
# upload: dataset/test/basset_hound/basset_hound_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_146.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_96.jpg
# upload: dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_80.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/american_pit_bull_terrier/american_pit_bull_terrier_80.jpg
# upload: dataset/test/basset_hound/basset_hound_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_17.jpg
# upload: dataset/test/basset_hound/basset_hound_182.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_182.jpg
# upload: dataset/test/basset_hound/basset_hound_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_183.jpg
# upload: dataset/test/basset_hound/basset_hound_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_50.jpg
# upload: dataset/test/basset_hound/basset_hound_197.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_197.jpg
# upload: dataset/test/basset_hound/basset_hound_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_19.jpg
# upload: dataset/test/basset_hound/basset_hound_53.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_53.jpg
# upload: dataset/test/basset_hound/basset_hound_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_65.jpg
# upload: dataset/test/basset_hound/basset_hound_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_8.jpg
# upload: dataset/test/basset_hound/basset_hound_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_82.jpg
# upload: dataset/test/basset_hound/basset_hound_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_188.jpg
# upload: dataset/test/basset_hound/basset_hound_41.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_41.jpg
# upload: dataset/test/basset_hound/basset_hound_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_88.jpg
# upload: dataset/test/basset_hound/basset_hound_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_61.jpg
# upload: dataset/test/basset_hound/basset_hound_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_176.jpg
# upload: dataset/test/basset_hound/basset_hound_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_70.jpg
# upload: dataset/test/basset_hound/basset_hound_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/basset_hound/basset_hound_96.jpg
# upload: dataset/test/beagle/beagle_14.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_14.jpg
# upload: dataset/test/beagle/beagle_186.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_186.jpg
# upload: dataset/test/beagle/beagle_187.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_187.jpg
# upload: dataset/test/beagle/beagle_149.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_149.jpg
# upload: dataset/test/beagle/beagle_18.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_18.jpg
# upload: dataset/test/beagle/beagle_125.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_125.jpg
# upload: dataset/test/beagle/beagle_193.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_193.jpg
# upload: dataset/test/beagle/beagle_191.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_191.jpg
# upload: dataset/test/beagle/beagle_173.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_173.jpg
# upload: dataset/test/beagle/beagle_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_61.jpg
# upload: dataset/test/beagle/beagle_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_70.jpg
# upload: dataset/test/beagle/beagle_41.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_41.jpg
# upload: dataset/test/beagle/beagle_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_65.jpg
# upload: dataset/test/beagle/beagle_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_82.jpg
# upload: dataset/test/beagle/beagle_20.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_20.jpg
# upload: dataset/test/beagle/beagle_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_8.jpg
# upload: dataset/test/beagle/beagle_53.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_53.jpg
# upload: dataset/test/beagle/beagle_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_50.jpg
# upload: dataset/test/beagle/beagle_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_88.jpg
# upload: dataset/test/boxer/boxer_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_137.jpg
# upload: dataset/test/boxer/boxer_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_123.jpg
# upload: dataset/test/boxer/boxer_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_176.jpg
# upload: dataset/test/boxer/boxer_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_146.jpg
# upload: dataset/test/beagle/beagle_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/beagle/beagle_96.jpg
# upload: dataset/test/boxer/boxer_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_17.jpg
# upload: dataset/test/boxer/boxer_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_188.jpg
# upload: dataset/test/boxer/boxer_182.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_182.jpg
# upload: dataset/test/boxer/boxer_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/test/boxer/boxer_183.jpg
# ...
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_50.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_65.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_67.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_67.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_74.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_74.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_6.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_6.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_70.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_113.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_113.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_71.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_71.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_91.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_91.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_90.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_90.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_102.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_102.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_78.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_78.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_8.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_138.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_138.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_123.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_126.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_126.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_18.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_18.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_146.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_137.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_171.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_171.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_182.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_182.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_17.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_180.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_180.jpg
# upload: dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/staffordshire_bull_terrier/staffordshire_bull_terrier_96.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_156.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_156.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_170.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_170.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_19.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_197.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_197.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_176.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_50.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_191.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_191.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_24.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_24.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_183.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_188.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_53.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_53.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_71.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_71.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_41.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_41.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_58.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_58.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_35.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_35.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_68.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_68.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_70.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_56.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_56.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_75.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_75.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_73.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_73.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_8.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_82.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_192.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_192.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_61.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_9.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_9.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_123.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_123.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_65.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_102.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_102.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_126.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_126.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_156.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_156.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_17.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_17.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_138.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_138.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_146.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_146.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_113.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_113.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_170.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_170.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_171.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_171.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_137.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_137.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_88.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_176.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_176.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_19.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_19.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_191.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_191.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_18.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_18.jpg
# upload: dataset/val/wheaten_terrier/wheaten_terrier_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/wheaten_terrier/wheaten_terrier_96.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_180.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_180.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_183.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_183.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_192.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_192.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_182.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_182.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_53.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_53.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_58.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_58.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_24.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_24.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_197.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_197.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_50.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_50.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_35.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_35.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_71.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_71.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_188.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_188.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_75.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_75.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_61.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_61.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_41.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_41.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_73.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_73.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_56.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_56.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_70.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_70.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_8.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_8.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_9.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_9.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_68.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_68.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_82.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_82.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_65.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_65.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_88.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_88.jpg
# upload: dataset/val/yorkshire_terrier/yorkshire_terrier_96.jpg to s3://sagemaker-us-east-2-322537213286/oxford_pet_dataset/val/yorkshire_terrier/yorkshire_terrier_96.jpg

# %% [markdown]
# ## 5. APEX 소개와 Model Source Code 작성
#
# AWS에서 Multigpu distributed training은 기본적으로 Horovod를 사용합니다. 이번에는 Pytorch에서 활용할 수 있는 [APEX](https://github.com/NVIDIA/apex) (A Pytorch EXtension) 패키지를 이용하여 Multigpu distributed training을 수행합니다. APEX 패키지에는 distributed training 기능과 함께 mixed precision training도 할 수 있도록 지원하고 있습니다.
#
#
# <p><img src="./imgs/apex.png" width="1100", height="150"></p>
# - mixed precision training (apex.amp) : FP16과 FP32연산을 mixed하여 처리 속도와 정확도를 동시에 잡기 위해 학습을 하는 방법입니다. Tensor Cores에서 FP16를 이용하면 compute 처리량은 8배, 메모리 처리량은 2배 증가하는 반면 메모리 저장은 50% 절감됩니다. (FP : Floating Point, AMP: Automatic Mixed Precision)
#
# - **DataParallel (DP)** : 데이터 샘플의 미니 배치를 여러 개의 더 작은 미니 배치로 나누고 병렬로 작은 미니 배치를 각각 계산하는 방식이며, 단일 host에서 multi-gpu인 경우와 cpu 연산일 경우에 사용합니다. DP의 단점은 GPU가 즐어나면서 communication 비용이 높아지게 되면서 성능저하가 발생하게 되는데 일반적으로 4 gpu 이상일 경우 발생한다고 합니다. 또한, 타 GPU 메모리 대비 0번 GPU 메모리 사용량이 증가하는 현상도 발생합니다.
#
#
# - **Distributed Data Parallel (DDP)** : 모듈 수준에서 데이터 병렬 처리를 구현하는 것으로 torch.distributed 패키지의 communication collectives를 사용하여 gradient, parameters, buffers를 동기화합니다. 프로세스 내와 프로세스 간을 사용하는 multi-host의 multi-gpu 와 같은 경우에 사용하게 되는데, 프로세스 내에서는 DDP는 input 모듈을 device_id에 특정한 device로 복제하고, 그에 따라 배치 크기로 input을 분산시키며, outputs는 DataParallel과 유사하게 output_device로 모으게 됩니다.
#
#
# - **[Horovod](https://distributed-training-workshop.go-aws.com/)** : MPI 개념을 기반으로 size, rank, local rank, allreduce, allgather, broadcast등을 이용합니다.
#
#
# - **[APEX](https://nvidia.github.io/apex)** : apex.parallel.DistributedDataParallel는 모듈 wrapper이며, DDP와 유사합니다. 편리하게 Multi-process를 통한 distributed training을 지원하고, NCCL에 최적화하여 지원합니다.

# %% [markdown]
# #### 1) 학습 스크립트 코딩하기
#
# <p>SageMaker에서 학습하는 것이 아니더라도 실제 모델 아키텍처와 학습을 위한 optimizer와 loss 함수 등을 정의하는 python 파일을 구성하게 됩니다. SageMaker에서 활용하는 python 파일도 동일한 python 파일을 사용하게 됩니다. 연계되는 다른 소스코드 파일이 있는 경우에도 별도 소스코드 수정 없이 학습이 가능하며, SageMaker에서 사용하기 위해서는 기존 python 파일에 SageMaker 학습에 사용할 수 있는 환경변수들만 추가하면 됩니다. 예를 들어, 환경변수 중 <code>SM_MODEL_DIR</code>은 컨테이너 환경에서는 <code>/opt/ml/model</code>를 의미합니다. 다양한 환경변수는 <strong><a href="https://github.com/aws/sagemaker-containers" target="_blank" class ='btn-default'>SageMaker Containers-IMPORTANT ENVIRONMENT VARIABLES</a></strong>를 참고하시기 바랍니다. </p><p>SageMaker 학습이 끝나면 자동은 컨테이너 환경은 삭제가 됩니다. 따라서, 학습이 완료된 모델 산출물과 다양한 output 파일은 S3로 저장해야 합니다. SageMaker는 자동으로 <code>SM_MODEL_DIR</code>에 저장된 최종 모델 파일을 학습이 끝난 다음 model.tar.gz로 압축하여 컨테이너 환경에서 S3의 특정 bucket에 저장하게 됩니다.</p><p> 별도 bucket을 설정하지 않으며, 기본적으로 생성되는 bucket에 저장됩니다. 이외 학습에 이용되는 python source code는 SageMaker 학습이 시작되면서 S3에 저장되며, 별도로 <code>SM_MODEL_DIR</code>에 checkpoint 또는 log 파일을 저장하게 되면 학습이 끝난 이후 자동으로 컨테이너 환경에서 S3로 저장된 파일들이 이동하게 됩니다. 이런 과정을 이해한다면 학습 시 저장되는 다양한 정보들을 저장한 다음 학습이 끝난 후 S3에서 download 받아 활용할 수 있습니다. </p>
#
# <p>아래는 시간 관계 상 미리 작성한 python 학습 스크립트 코드 입니다.</p>

# %%
# %%writefile ./src_dir/main_trainer.py

import argparse
import json
import logging
import os
import random
import sys
import time
import warnings
from functools import partial

import numpy as np
import torch
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import dis_util
import sagemaker_containers
import util

## Apex import package
try:
    from apex.parallel import DistributedDataParallel as DDP
    from apex.fp16_utils import *
    from apex import amp, optimizers
    from apex.multi_tensor_apply import multi_tensor_applier
except ImportError:
    raise ImportError(
        "Please install apex from https://www.github.com/nvidia/apex to run this example.")


logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler(sys.stdout))


def parser_args():
    parser = argparse.ArgumentParser()

    # Default Setting
    parser.add_argument('--log-interval', type=int, default=10, metavar='N',
                        help='how many batches to wait before logging training status')
    parser.add_argument('--backend', type=str, default='nccl',
                        help='backend for distributed training (tcp, gloo on cpu and gloo, nccl on gpu)')
    parser.add_argument('--channels-last', type=bool, default=True)
    parser.add_argument('--seed', type=int, default=1, metavar='S',
                        help='random seed (default: 1)')
    parser.add_argument('-p', '--print-freq', default=10, type=int,
                        metavar='N', help='print frequency (default: 10)')

    # Hyperparameter Setting
    parser.add_argument('--model_name', type=str, default='resnet50')
    parser.add_argument('--height', type=int, default=128)
    parser.add_argument('--width', type=int, default=128)
    parser.add_argument('--lr', type=float, default=0.001)
    parser.add_argument('--num_epochs', type=int, default=3)
    parser.add_argument('--batch-size', type=int, default=64)
    parser.add_argument('--test-batch-size', type=int, default=200, metavar='N',
                        help='input batch size for testing (default: 200)')

    # APEX Setting for Distributed Training
    parser.add_argument('--apex', type=bool, default=False)
    parser.add_argument('--opt-level', type=str, default='O0')
    parser.add_argument('--keep-batchnorm-fp32', type=str, default=None)
    parser.add_argument('--loss-scale', type=str, default=None)
    parser.add_argument('--sync_bn', action='store_true',
                        help='enabling apex sync BN.')
    parser.add_argument('--prof', default=-1, type=int,
                        help='Only run 10 iterations for profiling.')

    # SageMaker Container environment
    parser.add_argument('--hosts', type=list,
                        default=json.loads(os.environ['SM_HOSTS']))
    parser.add_argument('--current-host', type=str,
                        default=os.environ['SM_CURRENT_HOST'])
    parser.add_argument('--model-dir', type=str,
                        default=os.environ['SM_MODEL_DIR'])
    parser.add_argument('--data-dir', type=str,
                        default=os.environ['SM_CHANNEL_TRAINING'])
    parser.add_argument('--num-gpus', type=int,
                        default=os.environ['SM_NUM_GPUS'])
    parser.add_argument('--output_data_dir', type=str,
                        default=os.environ.get('SM_OUTPUT_DATA_DIR'))

    args = parser.parse_args()
    return args


def _get_train_data_loader(args, **kwargs):
    logger.info("Get train data loader")
    transform = transforms.Compose([
        transforms.Resize((args.width, args.height)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(brightness=0, contrast=0, saturation=0, hue=0),
        transforms.RandomAffine(
            0, translate=None, scale=None, shear=None, resample=False, fillcolor=0),
#         transforms.ToTensor(),  #Too slow
#         transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
    ])
    
    dataset = datasets.ImageFolder(root=os.path.join(args.data_dir, 'train'),
                                   transform=transform)
    train_sampler = data.distributed.DistributedSampler(
        dataset, num_replicas=int(args.world_size), rank=int(args.rank)) if args.multigpus_distributed else None
    return data.DataLoader(dataset, batch_size=args.batch_size, shuffle=train_sampler is None,
                                       sampler=train_sampler, collate_fn=dis_util.fast_collate, **kwargs), train_sampler


def _get_test_data_loader(args, **kwargs):
    logger.info("Get test data loader")
    transform = transforms.Compose([
        transforms.Resize((args.width, args.height)),
#         transforms.ToTensor(),
#         transforms.Normalize(
#             (0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
     
    dataset = datasets.ImageFolder(root=os.path.join(args.data_dir, 'val'),
                                   transform=transform)
    val_sampler = data.distributed.DistributedSampler(dataset) if args.multigpus_distributed else None
    return data.DataLoader(dataset, batch_size=args.test_batch_size, shuffle=False, 
                           sampler=val_sampler, collate_fn=dis_util.fast_collate, **kwargs)


def train(current_gpu, args):
    best_acc1 = -1
    model_history = {}
    model_history = util.init_modelhistory(model_history)
    train_start = time.time()

    ## choose model from pytorch model_zoo
    model = util.torch_model(args.model_name, pretrained=True)
    criterion = nn.CrossEntropyLoss().cuda()

    ## distributed_setting 
    model, args = dis_util.dist_setting(current_gpu, model, criterion, args)

    ## CuDNN library will benchmark several algorithms and pick that which it found to be fastest
    cudnn.benchmark = False if args.seed else True

    optimizer = optim.Adam(model.parameters(), lr=args.lr)

    if args.apex:
        model, optimizer = dis_util.apex_init(model, optimizer, args)
    
    
#     args.collate_fn = partial(dis_util.fast_collate, memory_format=args.memory_format)
    
    
    train_loader, train_sampler = _get_train_data_loader(args, **args.kwargs)
    test_loader = _get_test_data_loader(args, **args.kwargs)

    logger.info("Processes {}/{} ({:.0f}%) of train data".format(
        len(train_loader.sampler), len(train_loader.dataset),
        100. * len(train_loader.sampler) / len(train_loader.dataset)
    ))

    logger.info("Processes {}/{} ({:.0f}%) of test data".format(
        len(test_loader.sampler), len(test_loader.dataset),
        100. * len(test_loader.sampler) / len(test_loader.dataset)
    ))

    for epoch in range(1, args.num_epochs + 1):
        ## 
        batch_time = util.AverageMeter('Time', ':6.3f')
        data_time = util.AverageMeter('Data', ':6.3f')
        losses = util.AverageMeter('Loss', ':.4e')
        top1 = util.AverageMeter('Acc@1', ':6.2f')
        top5 = util.AverageMeter('Acc@5', ':6.2f')
        progress = util.ProgressMeter(
            len(train_loader),
            [batch_time, data_time, losses, top1, top5],
            prefix="Epoch: [{}]".format(epoch))

        model.train()
        end = time.time()
        
        ## Set epoch count for DistributedSampler
        if args.multigpus_distributed:
            train_sampler.set_epoch(epoch)
        
        
        prefetcher = util.data_prefetcher(train_loader)
        input, target = prefetcher.next()
        batch_idx = 0
        while input is not None:

            batch_idx += 1
            
            if args.prof >= 0 and batch_idx == args.prof:
                print("Profiling begun at iteration {}".format(batch_idx))
                torch.cuda.cudart().cudaProfilerStart()
                
            if args.prof >= 0: torch.cuda.nvtx.range_push("Body of iteration {}".format(batch_idx))

            util.adjust_learning_rate(optimizer, epoch, batch_idx, len(train_loader), args)

            # compute output
            if args.prof >= 0: torch.cuda.nvtx.range_push("forward")
            output = model(input)
            if args.prof >= 0: torch.cuda.nvtx.range_pop()
            loss = criterion(output, target)

            # compute gradient and do SGD step
            optimizer.zero_grad()
            
            if args.prof >= 0: torch.cuda.nvtx.range_push("backward")
            if args.apex:
                with amp.scale_loss(loss, optimizer) as scaled_loss:
                    scaled_loss.backward()
            else:
                loss.backward()
            if args.prof >= 0: torch.cuda.nvtx.range_pop()

            if args.prof >= 0: torch.cuda.nvtx.range_push("optimizer.step()")
            optimizer.step()
            if args.prof >= 0: torch.cuda.nvtx.range_pop()

            if True or batch_idx % args.log_interval == 0:
                # Every print_freq iterations, check the loss, accuracy, and speed.
                # For best performance, it doesn't make sense to print these metrics every
                # iteration, since they incur an allreduce and some host<->device syncs.

                # Measure accuracy
                prec1, prec5 = util.accuracy(output.data, target, topk=(1, 5))

                # Average loss and accuracy across processes for logging
                if args.multigpus_distributed:
                    reduced_loss = dis_util.reduce_tensor(loss.data, args)
                    prec1 = dis_util.reduce_tensor(prec1, args)
                    prec5 = dis_util.reduce_tensor(prec5, args)
                else:
                    reduced_loss = loss.data

                # to_python_float incurs a host<->device sync
                losses.update(to_python_float(reduced_loss), input.size(0))
                top1.update(to_python_float(prec1), input.size(0))
                top5.update(to_python_float(prec5), input.size(0))
                
                ## Waiting until finishing operations on GPU (Pytorch default: async)
                torch.cuda.synchronize()
                batch_time.update((time.time() - end)/args.log_interval)
                end = time.time()

                if current_gpu == 0:
                    print('Epoch: [{0}][{1}/{2}]  '
                          'Time {batch_time.val:.3f} ({batch_time.avg:.3f})  '
                          'Speed {3:.3f} ({4:.3f})  '
                          'Loss {loss.val:.10f} ({loss.avg:.4f})  '
                          'Prec@1 {top1.val:.3f} ({top1.avg:.3f})  '
                          'Prec@5 {top5.val:.3f} ({top5.avg:.3f})'.format(
                              epoch, batch_idx, len(train_loader),
                              args.world_size*args.batch_size/batch_time.val,
                              args.world_size*args.batch_size/batch_time.avg,
                              batch_time=batch_time,
                              loss=losses, top1=top1, top5=top5))
                    model_history['epoch'].append(epoch)
                    model_history['batch_idx'].append(batch_idx)
                    model_history['batch_time'].append(batch_time.val)
                    model_history['losses'].append(losses.val)
                    model_history['top1'].append(top1.val)
                    model_history['top5'].append(top5.val)
                    
                if args.prof >= 0: torch.cuda.nvtx.range_push("prefetcher.next()")
                input, target = prefetcher.next()
                if args.prof >= 0: torch.cuda.nvtx.range_pop()

                # Pop range "Body of iteration {}".format(i)
                if args.prof >= 0: torch.cuda.nvtx.range_pop()
                    

                if args.prof >= 0 and batch_idx == args.prof + 10:
                    print("Profiling ended at iteration {}".format(batch_idx))
                    torch.cuda.cudart().cudaProfilerStop()
                    quit()
               
        acc1 = validate(test_loader, model, criterion, epoch, model_history, args)
        
        print(" ****  acc1 :{}".format(acc1))
        # remember best acc@1 and save checkpoint
        is_best = acc1 > best_acc1
        best_acc1 = max(acc1, best_acc1)

        if not args.multigpus_distributed or (args.multigpus_distributed and args.rank % args.num_gpus == 0):
            util.save_history(os.path.join(args.output_data_dir,
                          'model_history.p'), model_history)

            util.save_model({
                'epoch': epoch + 1,
                'model_name': args.model_name,
                'state_dict': model.state_dict(),
                'best_acc1': best_acc1,
                'optimizer': optimizer.state_dict(),
                'class_to_idx' : train_loader.dataset.class_to_idx,
            }, is_best, args.model_dir)


def validate(val_loader, model, criterion, epoch, model_history, args):
    batch_time = util.AverageMeter('Time', ':6.3f')
    losses = util.AverageMeter('Loss', ':.4e')
    top1 = util.AverageMeter('Acc@1', ':6.2f')
    top5 = util.AverageMeter('Acc@5', ':6.2f')
    progress = util.ProgressMeter(
        len(val_loader),
        [batch_time, losses, top1, top5],
        prefix='Test: ')

    # switch to evaluate mode
    model.eval()
    end = time.time()

    prefetcher = util.data_prefetcher(val_loader)
    input, target = prefetcher.next()
    batch_idx = 0
    while input is not None:
        batch_idx += 1
    
        # compute output
        with torch.no_grad():
#             data = data.contiguous(memory_format=args.memory_format)
#             target = target.contiguous()
#             data = data.cuda(non_blocking=True)
#             target = target.cuda(non_blocking=True)

            output = model(input)
            loss = criterion(output, target)

        # measure accuracy and record loss
        prec1, prec5 = util.accuracy(output.data, target, topk=(1, 5))

        if args.multigpus_distributed:
            reduced_loss = dis_util.reduce_tensor(loss.data, args)
            prec1 = dis_util.reduce_tensor(prec1, args)
            prec5 = dis_util.reduce_tensor(prec5, args)
        else:
            reduced_loss = loss.data

        losses.update(to_python_float(reduced_loss), input.size(0))
        top1.update(to_python_float(prec1), input.size(0))
        top5.update(to_python_float(prec5), input.size(0))

        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()

        # TODO:  Change timings to mirror train().
        if args.current_gpu == 0 and batch_idx % args.log_interval == 0:
            print('Test: [{0}/{1}]  '
                  'Time {batch_time.val:.3f} ({batch_time.avg:.3f})  '
                  'Speed {2:.3f} ({3:.3f})  '
                  'Loss {loss.val:.4f} ({loss.avg:.4f})  '
                  'Prec@1 {top1.val:.3f} ({top1.avg:.3f})  '
                  'Prec@5 {top5.val:.3f} ({top5.avg:.3f})'.format(
                      batch_idx, len(val_loader),
                      args.world_size * args.batch_size / batch_time.val,
                      args.world_size * args.batch_size / batch_time.avg,
                      batch_time=batch_time, loss=losses,
                      top1=top1, top5=top5))
            model_history['val_epoch'].append(epoch)
            model_history['val_batch_idx'].append(batch_idx)
            model_history['val_batch_time'].append(batch_time.val)
            model_history['val_losses'].append(losses.val)
            model_history['val_top1'].append(top1.val)
            model_history['val_top5'].append(top5.val)
        input, target = prefetcher.next()

    print('  Prec@1 {top1.avg:.3f} Prec@5 {top5.avg:.3f}'
          .format(top1=top1, top5=top5))
    model_history['val_avg_epoch'].append(epoch)
    model_history['val_avg_batch_time'].append(batch_time.avg)
    model_history['val_avg_losses'].append(losses.avg)
    model_history['val_avg_top1'].append(top1.avg)
    model_history['val_avg_top5'].append(top5.avg)
    return top1.avg


def main():
    args = parser_args()
    args.use_cuda = args.num_gpus > 0
    print("args.use_cuda : {} , args.num_gpus : {}".format(
        args.use_cuda, args.num_gpus))
    args.kwargs = {'num_workers': 4,
                   'pin_memory': True} if args.use_cuda else {}
    args.device = torch.device("cuda" if args.use_cuda else "cpu")
    dis_util.dist_init(train, args)


if __name__ == '__main__':
    main()
# Out:
# Overwriting ./src_dir/main_trainer.py

# %% [markdown]
# #### 2) 분산/멀티 gpu에 필요한 code 작성
#
# apex사용과 분산을 위한 init 함수와 분산관련 다양한 함수를 제공합니다.

# %%
# %%writefile ./src_dir/dis_util.py

import argparse
import logging
import numpy as np
import os
import random
import sys
import warnings

import torch
import torch.backends.cudnn as cudnn
import torch.distributed as dist
import torch.multiprocessing as mp
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data.distributed

import sagemaker_containers

try:
    from apex.parallel import DistributedDataParallel as DDP
    from apex.fp16_utils import *
    from apex import amp, optimizers
    from apex.multi_tensor_apply import multi_tensor_applier
except ImportError:
    raise ImportError(
        "Please install apex from https://www.github.com/nvidia/apex to run this example.")


logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler(sys.stdout))


def dist_init(fn, args):
    if args.seed is not None:
        random.seed(args.seed)
        torch.manual_seed(args.seed)
        cudnn.deterministic = True
        warnings.warn('You have chosen to seed training. '
                      'This will turn on the CUDNN deterministic setting, '
                      'which can slow down your training considerably! '
                      'You may see unexpected behavior when restarting '
                      'from checkpoints.')

    args.is_distributed = len(args.hosts) > 1 and args.backend is not None
    args.is_multigpus = args.num_gpus > 1
    args.multigpus_distributed = (args.is_distributed or args.is_multigpus)

    logger.debug("Distributed training - {}".format(args.is_distributed))
    logger.debug("Number of gpus available - {}".format(args.num_gpus))

    args.world_size = 1
    if args.multigpus_distributed:
        # Initialize the distributed environment.
        args.apex = True
        args.world_size = len(args.hosts) * args.num_gpus
        os.environ['WORLD_SIZE'] = str(args.world_size)
        args.host_num = args.hosts.index(args.current_host)
        mp.spawn(fn, nprocs=args.num_gpus, args=(args,))
    else:
        current_gpu = 0
        fn(current_gpu, args)


def dist_setting(current_gpu, model, criterion, args):
    print("channels_last : {}".format(args.channels_last))
    if args.channels_last:
        args.memory_format = torch.channels_last
    else:
        args.memory_format = torch.contiguous_format

    if args.apex:
        args.lr = args.lr*float(args.batch_size*args.world_size)/256.
    args.current_gpu = current_gpu
    if args.current_gpu is not None:
        print("Use GPU: {} for training".format(args.current_gpu))

    if args.multigpus_distributed:
        args.rank = args.num_gpus * args.host_num + args.current_gpu
        dist.init_process_group(backend=args.backend,
                                rank=args.rank, world_size=args.world_size)
        logger.info('Initialized the distributed environment: \'{}\' backend on {} nodes. '.format(
            args.backend, dist.get_world_size()) + 'Current host rank is {}. Number of gpus: {}'.format(
            dist.get_rank(), args.num_gpus))

    if args.sync_bn:
        import apex
        print("using apex synced BN")
        model = apex.parallel.convert_syncbn_model(model)

    if args.multigpus_distributed:
        if args.current_gpu is not None:
            torch.cuda.set_device(args.current_gpu)
            args.batch_size = int(args.batch_size / args.num_gpus)
            if not args.apex:
                model.cuda(args.current_gpu)
                model = torch.nn.parallel.DistributedDataParallel(
                    model, device_ids=[args.current_gpu])
        else:
            if not args.apex:
                model.cuda()
                model = torch.nn.parallel.DistributedDataParallel(model)
    elif args.current_gpu is not None:
        torch.cuda.set_device(args.current_gpu)
        if not args.apex:
            model = model.cuda(args.current_gpu)
    else:
        if not args.apex:
            model = torch.nn.DataParallel(model).cuda()

    return model, args


def apex_init(model, optimizer, args):
    model = model.cuda().to(memory_format=args.memory_format)
    model, optimizer = amp.initialize(model, optimizer,
                                      opt_level=args.opt_level,
                                      keep_batchnorm_fp32=args.keep_batchnorm_fp32,
                                      loss_scale=args.loss_scale
                                      )
    if args.multigpus_distributed:
        model = DDP(model, delay_allreduce=True)
    return model, optimizer


def reduce_tensor(tensor, args):
    rt = tensor.clone()
    dist.all_reduce(rt, op=dist.reduce_op.SUM)
    rt /= args.world_size
    return rt


def fast_collate(batch, memory_format=torch.channels_last):
    imgs = [img[0] for img in batch]
    targets = torch.tensor([target[1] for target in batch], dtype=torch.int64)
    w = imgs[0].size[0]
    h = imgs[0].size[1]
    tensor = torch.zeros((len(imgs), 3, h, w), dtype=torch.uint8).contiguous(
        memory_format=memory_format)
    for i, img in enumerate(imgs):
        nump_array = np.array(img, dtype=np.uint8)
        if(nump_array.ndim < 3):
            nump_array = np.expand_dims(nump_array, axis=-1)
        nump_array = np.rollaxis(nump_array, 2)
        tensor[i] += torch.from_numpy(nump_array)
    return tensor, targets
# Out:
# Overwriting ./src_dir/dis_util.py

# %% [markdown]
# #### 3) 모델 학습에 공통적으로 사용할 수 있는 util 코드 작성

# %%
# %%writefile ./src_dir/util.py

import codecs
import json
import logging
import os
import shutil
import sys
import time


import torch
import torch.backends.cudnn as cudnn
import torch.distributed as dist
import torch.multiprocessing as mp
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data.distributed
from torchvision import models

import sagemaker_containers

logger = logging.getLogger(__name__)
logger.setLevel(logging.DEBUG)
logger.addHandler(logging.StreamHandler(sys.stdout))


def torch_model(model_name, pretrained=True):
    model_names = sorted(name for name in models.__dict__
                         if name.islower() and not name.startswith("__")
                         and callable(models.__dict__[name]))

    if(model_name == "inception_v3"):
        raise RuntimeError(
            "Currently, inception_v3 is not supported by this example.")

    # create model
    if pretrained:
        print("=> using pre-trained model '{}'".format(model_name))
        model = models.__dict__[model_name](pretrained=True)
    else:
        print("=> creating model '{}'".format(model_name))
        model = models.__dict__[model_name]()
    return model


def accuracy(output, target, topk=(1,)):
    """Computes the accuracy over the k top predictions for the specified values of k"""
    with torch.no_grad():
        maxk = max(topk)
        batch_size = target.size(0)

        _, pred = output.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(target.view(1, -1).expand_as(pred))

        res = []
        for k in topk:
            correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
            res.append(correct_k.mul_(100.0 / batch_size))
        return res


def save_model(state, is_best, model_dir):
    logger.info("Saving the model.")
    filename = os.path.join(model_dir, 'checkpoint.pth')
    # recommended way from http://pytorch.org/docs/master/notes/serialization.html
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, os.path.join(model_dir, 'model_best.pth'))


class AverageMeter(object):
    """Computes and stores the average and current value"""

    def __init__(self, name, fmt=':f'):
        self.name = name
        self.fmt = fmt
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

    def __str__(self):
        fmtstr = '{name} {val' + self.fmt + '} ({avg' + self.fmt + '})'
        return fmtstr.format(**self.__dict__)


class ProgressMeter(object):
    def __init__(self, num_batches, meters, prefix=""):
        self.batch_fmtstr = self._get_batch_fmtstr(num_batches)
        self.meters = meters
        self.prefix = prefix

    def display(self, batch):
        entries = [self.prefix + self.batch_fmtstr.format(batch)]
        entries += [str(meter) for meter in self.meters]
        print('\t'.join(entries))

    def _get_batch_fmtstr(self, num_batches):
        num_digits = len(str(num_batches // 1))
        fmt = '{:' + str(num_digits) + 'd}'
        return '[' + fmt + '/' + fmt.format(num_batches) + ']'

        
def adjust_learning_rate(optimizer, epoch, step, len_epoch, args):
    """LR schedule that should yield 76% converged accuracy with batch size 256"""
    factor = epoch // 30

    if epoch >= 80:
        factor = factor + 1

    lr = args.lr*(0.1**factor)

    """Warmup"""
    if epoch < 5:
        lr = lr*float(1 + step + epoch*len_epoch)/(5.*len_epoch)

    if(args.current_gpu == 0):
        print("epoch = {}, step = {}, lr = {}".format(epoch, step, lr))

    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
        
        
class data_prefetcher():
    def __init__(self, loader):
        self.loader = iter(loader)
        self.stream = torch.cuda.Stream()
        self.mean = torch.tensor([0.5 * 255, 0.5 * 255, 0.5 * 255]).cuda().view(1,3,1,1)
        self.std = torch.tensor([0.5 * 255, 0.5 * 255, 0.5 * 255]).cuda().view(1,3,1,1)
        self.preload()

    def preload(self):
        try:
            self.next_input, self.next_target = next(self.loader)
        except StopIteration:
            self.next_input = None
            self.next_target = None
            return

        with torch.cuda.stream(self.stream):
            self.next_input = self.next_input.cuda(non_blocking=True)
            self.next_target = self.next_target.cuda(non_blocking=True)
            self.next_input = self.next_input.float()
            self.next_input = self.next_input.sub_(self.mean).div_(self.std)

    def next(self):
        torch.cuda.current_stream().wait_stream(self.stream)
        input = self.next_input
        target = self.next_target
        if input is not None:
            input.record_stream(torch.cuda.current_stream())
        if target is not None:
            target.record_stream(torch.cuda.current_stream())
        self.preload()
        return input, target
    


def save_history(path, history):

    history_for_json = {}
    # transform float values that aren't json-serializable
    for key in history.keys():
        history_for_json[key] = list(map(float, history[key]))

    with codecs.open(path, 'w', encoding='utf-8') as f:
        json.dump(history_for_json, f, separators=(
            ',', ':'), sort_keys=True, indent=4)
        
        

def init_modelhistory(model_history):
    model_history['epoch'] = []
    model_history['batch_idx'] = []
    model_history['batch_time'] = []
    model_history['losses'] = []
    model_history['top1'] = []
    model_history['top5'] = []
    model_history['val_epoch'] = []
    model_history['val_batch_idx'] = []
    model_history['val_batch_time'] = []
    model_history['val_losses'] = []
    model_history['val_top1'] = []
    model_history['val_top5'] = []
    model_history['val_avg_epoch'] = []
    model_history['val_avg_batch_time'] = []
    model_history['val_avg_losses'] = []
    model_history['val_avg_top1'] = []
    model_history['val_avg_top5'] = []
    return model_history
# Out:
# Overwriting ./src_dir/util.py

# %% [markdown]
# ## 6.Hyperparameter 셋팅

# %%
hyperparameters = {
        'model_name' : 'wide_resnet50_2',
        'height' : 224,
        'width' : 224,
        'num_epochs': 50,
        'batch-size' : 32*8,
        'lr': 0.001
    }

# %%
## local 모드에서도 사용할 수 있으나 분산학습을 위해 gpu에서 학습 수행
# train_instance_type = 'local'
train_instance_type = 'ml.p3.8xlarge'
train_instance_count = 2

# %%
from sagemaker.local import LocalSession

if train_instance_type == 'local':
    sagemaker_session = LocalSession()
    sagemaker_session.config = {'local': {'local_code': True}}
    s3_data_path='file:///home/ec2-user/SageMaker/Sagemaker-HOL/3.Distributed_training_and_EIA_Deploy_for_Pytorch/dataset'
else:
    sagemaker_session = sagemaker.Session(sagemaker_client=sm)
    s3_data_path = 's3://{}/{}'.format(data_bucket, 'oxford_pet_dataset')

# %% [markdown]
# ## 7. `Pytorch` estimator를 이용한 training job 생성하기
#
#
# <p><strong><code>sagemaker.pytorch.PyTorch</code></strong> estimator는 처음 실행하는 스크립트 위치와 다양한 연계 코드들이 위치한 디렉토리 정보를 찾아서 스크립트를 S3에 upload하고 SageMaker의 training job을 수행하게 됩니다. training job은 학습을 수행한 단위입니다. 학습을 1번 돌리면 training job이 1개 생성됩니다. 몇 가지 중요 파라미터를 아래와 같이 설명드립니다. </p>
#
# - **entry_point** : 학습을 처음 실행하는 Python 소스 파일의 절대 또는 상대 경로이며, source_dir이 지정된 경우 entry_point는 source_dir 내 파일이 됩니다.
# - **source_dir** : 학습에 연계되는 다양한 소스코드 파일이 들어 있는 디렉토리 위치이며, 절대, 상대 경로 또는 S3 URI가 모두 가능하며,source_dir이 S3 URI 인 경우 tar.gz 파일이 됩니다.
# - **role** : Amazon SageMaker가 사용자를 대신해 작업(예: S3 버킷에서 모델 결과물이라고 하는 훈련 결과 읽기 및 Amazon S3에 훈련 결과 쓰기)을 수행하는 AWS Identity and Access Management(IAM) 역할입니다.
# - **train_instance_count** : 학습을 수행하는 instance 개수를 정의할 수 있습니다.
# - **train_instance_type** : 학습을 수행하는 instance 타입을 정의할 수 있습니다.
# - **train_volume_size** : 학습 인스턴스에 연결할 Amazon Elastic Block Store(Amazon EBS) 스토리지 볼륨의 크기(GB)입니다. File 모드를 사용할 경우 이 값이 훈련 데이터를 충분히 저장할 수 있는 크기여야 합니다(File 모드가 기본값)
# - **train_use_spot_instances** : 학습에서 SageMaker Managed Spot 인스턴스를 사용할지 여부를 지정합니다. 활성화되면 train_max_wait도 설정해야 합니다.
# - **train_max_run** : 최대 학습 시간을 설정할 수 있으며, 이 시간이 지나면 Amazon SageMaker는 현재 상태에 관계없이 작업을 종료합니다. (기본값 : 24 * 60 * 60)
# - **train_max_wait** : SageMaker Managed Spot 인스턴스를 기다리는 초 단위의 시간을 의미하는 것으로, 이 시간이 지나면 Amazon SageMaker는 스팟 인스턴스가 사용 가능해지기를 기다리는 것을 중지하며 결과는 fail이 됩니다.
# - **framework_version** : 학습에 사용될 특정 Pytorch 버전을 정의할 수 있습니다.
# - **py_version** : 컨테이너 환경이 python3일 경우 py3, python2일 경우 py2로 설정하면 됩니다. python2는 지원이 중단되었지만 기존 python2로 구성된 파일들을 지원하기 위해 현재 계속 사용할 수 있습니다. 없을 경우에는 기본적으로 py3 입니다.
# - **hyperparameters** : 학습에 사용할 하이퍼 파라미터를 정의할 수 있으며, 정의된 하이퍼 파라미터 값들은 모두 학습 컨테이너로 전송이 됩니다.
#
# <p> 추가적으로 분산/ 멀티 GPU 학습도 가능합니다. SageMaker는 <strong><a href="https://github.com/horovod/horovod" target="_blank" class ='btn-default'>Horovod</a></strong>에 최적화된 환경을 제공하고 있으며, Pytorch의 경우 1.5.0부터 기본 docker에서 apex를 지원합니다.</p>

# %%
# %%time

# all input configurations, parameters, and metrics specified in estimator 
# definition are automatically tracked
estimator = PyTorch(
    entry_point='./main_trainer.py',
    source_dir='./src_dir',
    role=role,
    sagemaker_session=sagemaker_session,
    framework_version='1.5.0',
    train_instance_count=train_instance_count,
    train_instance_type=train_instance_type,
    train_volume_size=400,
    hyperparameters=hyperparameters,
#     train_use_spot_instances=True,  # spot instance 활용
#     train_max_run=12*60*60,
#     train_max_wait=12*60*60
)
# Out:
# CPU times: user 61 µs, sys: 24 µs, total: 85 µs
# Wall time: 90.1 µs

# %% [markdown]
# ## 8. Fit 함수로 학습 시작하기
#
# <p>학습을 시작하는 것은 <strong><code>estimator.fit (training_data_uri)</code></strong>이 호출되는 경우입니다. 여기에서 실제 데이터가 있는 S3의 위치가 입력으로 사용됩니다. <code>fit</code>에서는 <code>training</code>라는 기본 채널을 생성하며, 이 위치의 데이터는 S3에서 실제 컨테이너 환경에서는 <code>SM_CHANNEL_TRAINING</code> 위치로 복사되어 학습에 활용이 가능합니다. <code>fit</code>은 몇 가지 다른 유형의 입력도 허용하는데 자세한 내용은 <strong><a href="https://sagemaker.readthedocs.io/en/stable/estimators.html#sagemaker.estimator.EstimatorBase.fit" target="_blank" class ='btn-default'>API 문서</a></strong>를 참고하실 수 있습니다.</p>
# <p> 학습이 시작되면 Tensorflow 컨테이너에서는 <code>image_classifier.py</code>를 실행되며, <code>Estimator</code>에서 <code>hyperparameters</code> 와 <code>model_dir</code>을 스크립트의 파라미터로 전달합니다. <code>model_dir</code>을 별도로 전달하지 않으며, 기본값은<strong>s3://[DEFAULT_BUCKET]/[TRAINING_JOB_NAME] </strong>이 되며 실제 스크립트 실행은 다음과 같습니다. </p>
#
# ```bash
# python image_classifier.py --model_dir s3://[DEFAULT_BUCKET]/[TRAINING_JOB_NAME]
# ```
# <p>학습이 완료되면 training job은 Tensorflow serving을 위해 saved model을 S3에 upload합니다.</p>
# <p><code>fit</code>에서 <strong>wait=True</strong>로 설정할 경우 <strong>Synchronous</strong> 방식으로 동직하게 되며, <strong>wait=False</strong>일 경우 <strong>Aynchronous</strong> 방식으로 동작되어 여러 개의 Training job을 동시에 실행할 수 있습니다. </p>

# %%
training_job_name = "training-job-{}".format(int(time.time()))

# Now associate the estimator with the Experiment and Trial
estimator.fit(
    inputs={'training': s3_data_path}, 
    job_name=training_job_name,
    logs='All',
    wait=False,
)
estimator.fit
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# ---------------------------------------------------------------------------
# ParamValidationError                      Traceback (most recent call last)
# <ipython-input-52-a45c57d485f5> in <module>
#       6     job_name=training_job_name,
#       7     logs='All',
# ----> 8     wait=False,
#       9 )
#      10 estimator.fit
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     492         self._prepare_for_training(job_name=job_name)
#     493
# --> 494         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     495         self.jobs.append(self.latest_training_job)
#     496         if wait:
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1064             train_args["enable_sagemaker_metrics"] = estimator.enable_sagemaker_metrics
#    1065
# -> 1066         estimator.sagemaker_session.train(**train_args)
#    1067
#    1068         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image, algorithm_arn, encrypt_inter_container_traffic, train_use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics)
#     588         LOGGER.info("Creating training-job with name: %s", job_name)
#     589         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 590         self.sagemaker_client.create_training_job(**train_request)
#     591
#     592     def process(
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     606         }
#     607         request_dict = self._convert_to_request_dict(
# --> 608             api_params, operation_model, context=request_context)
#     609
#     610         service_id = self._service_model.service_id.hyphenize()
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/botocore/client.py in _convert_to_request_dict(self, api_params, operation_model, context)
#     654             api_params, operation_model, context)
#     655         request_dict = self._serializer.serialize_to_request(
# --> 656             api_params, operation_model)
#     657         if not self._client_config.inject_host_prefix:
#     658             request_dict.pop('host_prefix', None)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/botocore/validate.py in serialize_to_request(self, parameters, operation_model)
#     295                                                     operation_model.input_shape)
#     296             if report.has_errors():
# --> 297                 raise ParamValidationError(report=report.generate_report())
#     298         return self._serializer.serialize_to_request(parameters,
#     299                                                      operation_model)
#
# ParamValidationError: Parameter validation failed:
# Invalid length for parameter InputDataConfig[0].DataSource.FileSystemDataSource.FileSystemId, value: 4, valid range: 11-inf

# %%
job_name=estimator.latest_training_job.name
# job_name='training-job-1595416953'

# %% [markdown]
# <p><strong>Aynchronous</strong>로 진행된 Training job은 아래와 같은 방법으로 진행상황을 실시간으로 확인할 수 있습니다.</p>

# %%
sagemaker_session.logs_for_job(job_name=job_name, wait=True)
# Out:
# 2020-07-22 23:54:20 Starting - Launching requested ML instances............
# 2020-07-22 23:55:53 Starting - Preparing the instances for training......
# 2020-07-22 23:56:53 Downloading - Downloading input data...
# 2020-07-22 23:57:42 Training - Downloading the training image....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-07-22 23:58:25,361 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-07-22 23:58:25,404 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-07-22 23:58:26,818 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-07-22 23:58:27,071 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2020-07-22 23:58:27,071 sagemaker-containers INFO     Generating setup.cfg
# 2020-07-22 23:58:27,071 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-07-22 23:58:27,071 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install .
# Processing /tmp/tmpp3xfvqzt/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=27987 sha256=ebe9742f6c07b0f6202b8339c7473e2464db7b6a0dc360c24681eff35ddec760
#   Stored in directory: /tmp/pip-ephem-wheel-cache-14_osvqi/wheels/30/b7/69/0eb8374d35a89a90ae513a5c58994644ef3ee88a15347a590a
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# 2020-07-22 23:58:29,438 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "model_name": "wide_resnet50_2",
#         "lr": 0.001,
#         "width": 224,
#         "num_epochs": 50,
#         "height": 224
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "training-job-1595462057",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-322537213286/training-job-1595462057/source/sourcedir.tar.gz",
#     "module_name": "./main_trainer",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "./main_trainer.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"height":224,"lr":0.001,"model_name":"wide_resnet50_2","num_epochs":50,"width":224}
# SM_USER_ENTRY_POINT=./main_trainer.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=./main_trainer
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-322537213286/training-job-1595462057/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":256,"height":224,"lr":0.001,"model_name":"wide_resnet50_2","num_epochs":50,"width":224},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"training-job-1595462057","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-322537213286/training-job-1595462057/source/sourcedir.tar.gz","module_name":"./main_trainer","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"./main_trainer.py"}
# SM_USER_ARGS=["--batch-size","256","--height","224","--lr","0.001","--model_name","wide_resnet50_2","--num_epochs","50","--width","224"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=256
# SM_HP_MODEL_NAME=wide_resnet50_2
# SM_HP_LR=0.001
# SM_HP_WIDTH=224
# SM_HP_NUM_EPOCHS=50
# SM_HP_HEIGHT=224
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python ./main_trainer.py --batch-size 256 --height 224 --lr 0.001 --model_name wide_resnet50_2 --num_epochs 50 --width 224
#
#
# bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-07-22 23:58:24,923 sagemaker-containers INFO     Imported framework sagemaker_pytorch_container.training
# 2020-07-22 23:58:24,966 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2020-07-22 23:58:26,420 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2020-07-22 23:58:26,694 sagemaker-containers INFO     Module default_user_module_name does not provide a setup.py.
# Generating setup.py
# 2020-07-22 23:58:26,694 sagemaker-containers INFO     Generating setup.cfg
# 2020-07-22 23:58:26,695 sagemaker-containers INFO     Generating MANIFEST.in
# 2020-07-22 23:58:26,695 sagemaker-containers INFO     Installing module with the following command:
# /opt/conda/bin/python -m pip install .
# Processing /tmp/tmpd15yr4dp/module_dir
# Building wheels for collected packages: default-user-module-name
#   Building wheel for default-user-module-name (setup.py): started
#   Building wheel for default-user-module-name (setup.py): finished with status 'done'
#   Created wheel for default-user-module-name: filename=default_user_module_name-1.0.0-py2.py3-none-any.whl size=27987 sha256=ebe9742f6c07b0f6202b8339c7473e2464db7b6a0dc360c24681eff35ddec760
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a61jm0ok/wheels/76/43/9a/5bd01b1627443c871026b7cd50fe50dad521c4b344caeea65a
# Successfully built default-user-module-name
# Installing collected packages: default-user-module-name
# Successfully installed default-user-module-name-1.0.0
# WARNING: You are using pip version 20.1; however, version 20.1.1 is available.
# You should consider upgrading via the '/opt/conda/bin/python -m pip install --upgrade pip' command.
# 2020-07-22 23:58:29,288 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "batch-size": 256,
#         "model_name": "wide_resnet50_2",
#         "lr": 0.001,
#         "width": 224,
#         "num_epochs": 50,
#         "height": 224
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "training-job-1595462057",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-2-322537213286/training-job-1595462057/source/sourcedir.tar.gz",
#     "module_name": "./main_trainer",
#     "network_interface_name": "eth0",
#     "num_cpus": 32,
#     "num_gpus": 4,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "./main_trainer.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"height":224,"lr":0.001,"model_name":"wide_resnet50_2","num_epochs":50,"width":224}
# SM_USER_ENTRY_POINT=./main_trainer.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=./main_trainer
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=32
# SM_NUM_GPUS=4
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-2-322537213286/training-job-1595462057/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":256,"height":224,"lr":0.001,"model_name":"wide_resnet50_2","num_epochs":50,"width":224},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"training-job-1595462057","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-2-322537213286/training-job-1595462057/source/sourcedir.tar.gz","module_name":"./main_trainer","network_interface_name":"eth0","num_cpus":32,"num_gpus":4,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"./main_trainer.py"}
# SM_USER_ARGS=["--batch-size","256","--height","224","--lr","0.001","--model_name","wide_resnet50_2","--num_epochs","50","--width","224"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_BATCH-SIZE=256
# SM_HP_MODEL_NAME=wide_resnet50_2
# SM_HP_LR=0.001
# SM_HP_WIDTH=224
# SM_HP_NUM_EPOCHS=50
# SM_HP_HEIGHT=224
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python ./main_trainer.py --batch-size 256 --height 224 --lr 0.001 --model_name wide_resnet50_2 --num_epochs 50 --width 224
#
#
# args.use_cuda : True , args.num_gpus : 4
# Distributed training - True
# Number of gpus available - 4
# args.use_cuda : True , args.num_gpus : 4
# Distributed training - True
# Number of gpus available - 4
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# => using pre-trained model 'wide_resnet50_2'
# 2020-07-22 23:58:24 Training - Training image download completed. Training in progress.channels_last : True
# Use GPU: 2 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 6. Number of gpus: 4
# channels_last : True
# Use GPU: 3 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 7. Number of gpus: 4
# channels_last : True
# Use GPU: 1 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 5. Number of gpus: 4
# channels_last : True
# Use GPU: 0 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 4. Number of gpus: 4
# channels_last : True
# Use GPU: 0 for training
# channels_last : True
# Use GPU: 2 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 2. Number of gpus: 4
# channels_last : True
# Use GPU: 3 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 3. Number of gpus: 4
# channels_last : True
# Use GPU: 1 for training
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 1. Number of gpus: 4
# Initialized the distributed environment: 'nccl' backend on 8 nodes. Current host rank is 0. Number of gpus: 4
# Selected optimization level O0:  Pure FP32 training.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O0
# cast_model_type        : torch.float32
# patch_torch_functions  : False
# keep_batchnorm_fp32    : None
# master_weights         : False
# loss_scale             : 1.0
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O0
# cast_model_type        : torch.float32
# patch_torch_functions  : False
# keep_batchnorm_fp32    : None
# master_weights         : False
# loss_scale             : 1.0
# NCCL version 2.4.8+cuda10.1
# Get train data loader
# Get train data loader
# Get test data loader
# Get test data loader
# Processes 739/5910 (13%) of train data
# Processes 739/5910 (13%) of train data
# Processes 185/1478 (13%) of test data
# Processes 185/1478 (13%) of test data
# Get train data loader
# Get train data loader
# Get test data loader
# Processes 739/5910 (13%) of train data
# Processes 185/1478 (13%) of test data
# Get test data loader
# Processes 739/5910 (13%) of train data
# Processes 185/1478 (13%) of test data
# Get train data loader
# Get train data loader
# Get train data loader
# Get test data loader
# Get test data loader
# Processes 739/5910 (13%) of train data
# Processes 739/5910 (13%) of train data
# Processes 185/1478 (13%) of test data
# Processes 185/1478 (13%) of test data
# Get train data loader
# Get test data loader
# Processes 739/5910 (13%) of train data
# Processes 185/1478 (13%) of test data
# Get test data loader
# Processes 739/5910 (13%) of train data
# Processes 185/1478 (13%) of test data
# epoch = 1, step = 1, lr = 0.0018666666666666666
# [2020-07-22 23:58:47.430 algo-2:106 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-07-22 23:58:47.430 algo-2:106 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-07-22 23:58:47.430 algo-2:106 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [2020-07-22 23:58:47.431 algo-2:105 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-07-22 23:58:47.431 algo-2:105 INFO hook.py:183] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-07-22 23:58:47.431 algo-2:105 INFO hook.py:228] Saving to /opt/ml/output/tensors
# [2020-07-22 23:58:47.434 algo-2:106 INFO hook.py:364] Monitoring the collections: losses
# [2020-07-22 23:58:47.434 algo-2:105 INFO hook.py:364] Monitoring the collections: losses
# [2020-07-22 23:58:47.486 algo-2:107 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020
# Epoch: [1][11/12]  Time 0.217 (0.292)  Speed 2354.408 (1751.123)  Loss 2.9592413902 (4.2053)  Prec@1 15.820 (9.641)  Prec@5 49.414 (31.357)
# epoch = 1, step = 12, lr = 0.0033333333333333335
# Epoch: [1][11/12]  Time 0.217 (0.292)  Speed 2354.409 (1751.974)  Loss 2.9592413902 (4.2053)  Prec@1 15.820 (9.641)  Prec@5 49.414 (31.357)
# epoch = 1, step = 12, lr = 0.0033333333333333335
# Epoch: [1][12/12]  Time 0.161 (0.281)  Speed 3175.107 (1819.951)  Loss 2.8782434464 (4.1425)  Prec@1 21.786 (10.217)  Prec@5 56.071 (32.527)
# Epoch: [1][12/12]  Time 0.161 (0.281)  Speed 3175.114 (1819.110)  Loss 2.8782434464 (4.1425)  Prec@1 21.786 (10.217)  Prec@5 56.071 (32.527)
#   Prec@1 2.703 Prec@5 13.311
#   Prec@1 2.703 Prec@5 13.311
#   Prec@1 2.703 Prec@5 13.311
#   Prec@1 2.703 Prec@5 13.311
#  ****  acc1 :2.702702522277832
#  ****  acc1 :2.702702522277832
#  ****  acc1 :2.702702522277832
#  ****  acc1 :2.702702522277832
# Saving the model.
#   Prec@1 2.703 Prec@5 13.311
#   Prec@1 2.703 Prec@5 13.311
#   Prec@1 2.703 Prec@5 13.311
#   Prec@1 2.703 Prec@5 13.311
#  ****  acc1 :2.702702522277832
#  ****  acc1 :2.702702522277832
#  ****  acc1 :2.702702522277832
#  ****  acc1 :2.702702522277832
# Saving the model.
# epoch = 2, step = 1, lr = 0.003466666666666667
# epoch = 2, step = 1, lr = 0.003466666666666667
# Epoch: [2][1/12]  Time 0.789 (0.789)  Speed 648.757 (648.757)  Loss 2.9753794670 (2.9754)  Prec@1 15.234 (15.234)  Prec@5 52.539 (52.539)
# epoch = 2, step = 2, lr = 0.0036
# Epoch: [2][1/12]  Time 0.788 (0.788)  Speed 650.077 (650.077)  Loss 2.9753794670 (2.9754)  Prec@1 15.234 (15.234)  Prec@5 52.539 (52.539)
# epoch = 2, step = 2, lr = 0.0036
# Epoch: [2][2/12]  Time 0.218 (0.503)  Speed 2352.975 (1017.085)  Loss 2.8397960663 (2.9076)  Prec@1 18.164 (16.699)  Prec@5 53.516 (53.027)
# epoch = 2, step = 3, lr = 0.0037333333333333333
# Epoch: [2][2/12]  Time 0.218 (0.503)  Speed 2352.979 (1018.708)  Loss 2.8397960663 (2.9076)  Prec@1 18.164 (16.699)  Prec@5 53.516 (53.027)
# epoch = 2, step = 3, lr = 0.0037333333333333333
# Epoch: [2][3/12]  Time 0.217 (0.408)  Speed 2355.211 (1256.354)  Loss 2.6947631836 (2.8366)  Prec@1 21.484 (18.294)  Prec@5 60.742 (55.599)
# epoch = 2, step = 4, lr = 0.0038666666666666667
# Epoch: [2][3/12]  Time 0.217 (0.408)  Speed 2355.212 (1254.708)  Loss 2.6947631836 (2.8366)  Prec@1 21.484 (18.294)  Prec@5 60.742 (55.599)
# epoch = 2, step = 4, lr = 0.0038666666666666667
# Epoch: [2][10/12]  Time 0.217 (0.274)  Speed 2355.731 (1867.028)  Loss 2.4795994759 (2.6229)  Prec@1 25.977 (23.574)  Prec@5 68.750 (62.852)
# Epoch: [2][11/12]  Time 0.216 (0.269)  Speed 2368.164 (1904.685)  Loss 2.3169207573 (2.5951)  Prec@1 32.227 (24.361)  Prec@5 70.703 (63.565)
# epoch = 2, step = 11, lr = 0.0048000000000000004
# Epoch: [2][11/12]  Time 0.216 (0.269)  Speed 2368.165 (1903.649)  Loss 2.3169207573 (2.5951)  Prec@1 32.227 (24.361)  Prec@5 70.703 (63.565)
# epoch = 2, step = 12, lr = 0.004933333333333333
# epoch = 2, step = 12, lr = 0.004933333333333333
# Epoch: [2][12/12]  Time 0.196 (0.263)  Speed 2606.780 (1948.416)  Loss 2.5296983719 (2.5920)  Prec@1 23.929 (24.340)  Prec@5 65.357 (63.650)
# Epoch: [2][12/12]  Time 0.196 (0.263)  Speed 2606.811 (1947.424)  Loss 2.5296983719 (2.5920)  Prec@1 23.929 (24.340)  Prec@5 65.357 (63.650)
#   Prec@1 4.189 Prec@5 19.324
#   Prec@1 4.189 Prec@5 19.324
#   Prec@1 4.189 Prec@5 19.324
#   Prec@1 4.189 Prec@5 19.324
#  ****  acc1 :4.1891889572143555
#  ****  acc1 :4.1891889572143555
#  ****  acc1 :4.1891889572143555
#  ****  acc1 :4.1891889572143555
# Saving the model.
#   Prec@1 4.189 Prec@5 19.324
#   Prec@1 4.189 Prec@5 19.324
#   Prec@1 4.189 Prec@5 19.324
#   Prec@1 4.189 Prec@5 19.324
#  ****  acc1 :4.1891889572143555
#  ****  acc1 :4.1891889572143555
#  ****  acc1 :4.1891889572143555
#  ****  acc1 :4.1891889572143555
# Saving the model.
# epoch = 3, step = 1, lr = 0.005066666666666666
# Epoch: [3][1/12]  Time 0.857 (0.857)  Speed 597.727 (597.727)  Loss 2.2103698254 (2.2104)  Prec@1 31.836 (31.836)  Prec@5 74.219 (74.219)
# epoch = 3, step = 2, lr = 0.0052
# Epoch: [3][2/12]  Time 0.218 (0.537)  Speed 2349.319 (952.989)  Loss 2.1287398338 (2.1696)  Prec@1 32.812 (32.324)  Prec@5 77.148 (75.684)
# epoch = 3, step = 3, lr = 0.005333333333333333
# Epoch: [3][3/12]  Time 0.218 (0.431)  Speed 2353.710 (1188.815)  Loss 2.0929412842 (2.1440)  Prec@1 37.500 (34.049)  Prec@5 77.148 (76.172)
# epoch = 3, step = 4, lr = 0.0054666666666666665
# Epoch: [3][4/12]  Time 0.217 (0.377)  Speed 2355.377 (1356.814)  Loss 2.1388602257 (2.1427)  Prec@1 32.617 (33.691)  Prec@5 74.805 (75.830)
# epoch = 3, step = 5, lr = 0.0056
# epoch = 3, step = 1, lr = 0.005066666666666666
# Epoch: [3][1/12]  Time 0.773 (0.773)  Speed 661.929 (661.929)  Loss 2.2103698254 (2.2104)  Prec@1 31.836 (31.836)  Prec@5 74.219 (74.219)
# epoch = 3, step = 2, lr = 0.0052
# Epoch: [3][10/12]  Time 0.216 (0.281)  Speed 2369.492 (1822.489)  Loss 2.0171079636 (2.0824)  Prec@1 40.039 (36.660)  Prec@5 78.906 (77.930)
# epoch = 3, step = 11, lr = 0.0064
# Epoch: [3][10/12]  Time 0.216 (0.273)  Speed 2369.485 (1878.033)  Loss 2.0171079636 (2.0824)  Prec@1 40.039 (36.660)  Prec@5 78.906 (77.930)
# epoch = 3, step = 11, lr = 0.0064
# Epoch: [3][11/12]  Time 0.216 (0.275)  Speed 2373.227 (1861.766)  Loss 1.8730344772 (2.0633)  Prec@1 40.625 (37.021)  Prec@5 81.445 (78.249)
# epoch = 3, step = 12, lr = 0.006533333333333334
# Epoch: [3][12/12]  Time 0.145 (0.264)  Speed 3521.462 (1937.878)  Loss 2.1695485115 (2.0684)  Prec@1 36.429 (36.993)  Prec@5 75.000 (78.095)
# Epoch: [3][11/12]  Time 0.216 (0.267)  Speed 2373.252 (1914.348)  Loss 1.8730344772 (2.0633)  Prec@1 40.625 (37.021)  Prec@5 81.445 (78.249)
# epoch = 3, step = 12, lr = 0.006533333333333334
# Epoch: [3][12/12]  Time 0.145 (0.257)  Speed 3521.427 (1990.030)  Loss 2.1695485115 (2.0684)  Prec@1 36.429 (36.993)  Prec@5 75.000 (78.095)
#   Prec@1 5.405 Prec@5 24.797
#   Prec@1 5.405 Prec@5 24.797
#   Prec@1 5.405 Prec@5 24.797
#   Prec@1 5.405 Prec@5 24.797
#  ****  acc1 :5.405405044555664
#  ****  acc1 :5.405405044555664
#  ****  acc1 :5.405405044555664
#  ****  acc1 :5.405405044555664
# Saving the model.
#   Prec@1 5.405 Prec@5 24.797
#   Prec@1 5.405 Prec@5 24.797
#   Prec@1 5.405 Prec@5 24.797
#   Prec@1 5.405 Prec@5 24.797
#  ****  acc1 :5.405405044555664
#  ****  acc1 :5.405405044555664
#  ****  acc1 :5.405405044555664
#  ****  acc1 :5.405405044555664
# Saving the model.
# epoch = 4, step = 1, lr = 0.006666666666666667
# epoch = 4, step = 1, lr = 0.006666666666666667
# Epoch: [4][1/12]  Time 0.797 (0.797)  Speed 642.274 (642.274)  Loss 1.8579814434 (1.8580)  Prec@1 39.453 (39.453)  Prec@5 82.617 (82.617)
# epoch = 4, step = 2, lr = 0.0068000000000000005
# Epoch: [4][1/12]  Time 0.784 (0.784)  Speed 653.103 (653.103)  Loss 1.8579814434 (1.8580)  Prec@1 39.453 (39.453)  Prec@5 82.617 (82.617)
# epoch = 4, step = 2, lr = 0.0068000000000000005
# Epoch: [4][2/12]  Time 0.216 (0.507)  Speed 2365.045 (1010.207)  Loss 1.8712081909 (1.8646)  Prec@1 42.383 (40.918)  Prec@5 80.859 (81.738)
# epoch = 4, step = 3, lr = 0.006933333333333334
# Epoch: [4][2/12]  Time 0.216 (0.500)  Speed 2365.007 (1023.550)  Loss 1.8712081909 (1.8646)  Prec@1 42.383 (40.918)  Prec@5 80.859 (81.738)
# epoch = 4, step = 3, lr = 0.006933333333333334
# Epoch: [4][10/12]  Time 0.216 (0.273)  Speed 2366.763 (1872.193)  Loss 1.6516206264 (1.7499)  Prec@1 47.070 (45.547)  Prec@5 86.523 (85.000)
# epoch = 4, step = 11, lr = 0.008
# Epoch: [4][11/12]  Time 0.218 (0.268)  Speed 2353.308 (1907.648)  Loss 1.7101901770 (1.7463)  Prec@1 44.531 (45.455)  Prec@5 83.594 (84.872)
# epoch = 4, step = 12, lr = 0.008133333333333333
# Epoch: [4][12/12]  Time 0.146 (0.258)  Speed 3515.132 (1983.226)  Loss 1.7898919582 (1.7484)  Prec@1 42.143 (45.298)  Prec@5 83.571 (84.811)
# Epoch: [4][9/12]  Time 0.218 (0.281)  Speed 2347.422 (1820.178)  Loss 1.6179900169 (1.7608)  Prec@1 49.609 (45.378)  Prec@5 86.914 (84.831)
# epoch = 4, step = 10, lr = 0.007866666666666668
# Epoch: [4][10/12]  Time 0.216 (0.275)  Speed 2366.803 (1863.210)  Loss 1.6516206264 (1.7499)  Prec@1 47.070 (45.547)  Prec@5 86.523 (85.000)
# epoch = 4, step = 11, lr = 0.008
# Epoch: [4][11/12]  Time 0.218 (0.270)  Speed 2353.369 (1899.170)  Loss 1.7101901770 (1.7463)  Prec@1 44.531 (45.455)  Prec@5 83.594 (84.872)
# epoch = 4, step = 12, lr = 0.008133333333333333
# Epoch: [4][12/12]  Time 0.146 (0.259)  Speed 3515.125 (1974.825)  Loss 1.7898919582 (1.7484)  Prec@1 42.143 (45.298)  Prec@5 83.571 (84.811)
#   Prec@1 20.946 Prec@5 51.486
#   Prec@1 20.946 Prec@5 51.486
#   Prec@1 20.946 Prec@5 51.486
#   Prec@1 20.946 Prec@5 51.486
#  ****  acc1 :20.945945739746094
#  ****  acc1 :20.945945739746094
#  ****  acc1 :20.945945739746094
#  ****  acc1 :20.945945739746094
# Saving the model.
#   Prec@1 20.946 Prec@5 51.486
#   Prec@1 20.946 Prec@5 51.486
#   Prec@1 20.946 Prec@5 51.486
#   Prec@1 20.946 Prec@5 51.486
#  ****  acc1 :20.945945739746094
#  ****  acc1 :20.945945739746094
#  ****  acc1 :20.945945739746094
#  ****  acc1 :20.945945739746094
# Saving the model.
# epoch = 5, step = 1, lr = 0.008
# Epoch: [5][1/12]  Time 0.778 (0.778)  Speed 658.056 (658.056)  Loss 1.6103615761 (1.6104)  Prec@1 49.805 (49.805)  Prec@5 88.281 (88.281)
# epoch = 5, step = 2, lr = 0.008
# Epoch: [5][2/12]  Time 0.217 (0.498)  Speed 2357.575 (1028.916)  Loss 1.6118731499 (1.6111)  Prec@1 49.219 (49.512)  Prec@5 86.719 (87.500)
# epoch = 5, step = 3, lr = 0.008
# epoch = 5, step = 1, lr = 0.008
# Epoch: [5][1/12]  Time 0.776 (0.776)  Speed 660.142 (660.142)  Loss 1.6103615761 (1.6104)  Prec@1 49.805 (49.805)  Prec@5 88.281 (88.281)
# epoch = 5, step = 2, lr = 0.008
# Epoch: [5][2/12]  Time 0.217 (0.496)  Speed 2357.613 (1031.468)  Loss 1.6118731499 (1.6111)  Prec@1 49.219 (49.512)  Prec@5 86.719 (87.500)
# epoch = 5, step = 10, lr = 0.008
# Epoch: [5][9/12]  Time 0.217 (0.279)  Speed 2359.763 (1835.552)  Loss 1.8346443176 (1.5997)  Prec@1 47.656 (50.521)  Prec@5 83.984 (87.565)
# epoch = 5, step = 10, lr = 0.008
# Epoch: [5][10/12]  Time 0.217 (0.273)  Speed 2357.067 (1877.084)  Loss 1.3449357748 (1.5742)  Prec@1 56.836 (51.152)  Prec@5 90.820 (87.891)
# epoch = 5, step = 11, lr = 0.008
# Epoch: [5][10/12]  Time 0.217 (0.273)  Speed 2357.143 (1878.789)  Loss 1.3449357748 (1.5742)  Prec@1 56.836 (51.152)  Prec@5 90.820 (87.891)
# epoch = 5, step = 11, lr = 0.008
# Epoch: [5][11/12]  Time 0.217 (0.268)  Speed 2357.079 (1912.489)  Loss 1.5142362118 (1.5687)  Prec@1 54.102 (51.420)  Prec@5 88.086 (87.908)
# Epoch: [5][11/12]  Time 0.217 (0.267)  Speed 2357.062 (1914.097)  Loss 1.5142362118 (1.5687)  Prec@1 54.102 (51.420)  Prec@5 88.086 (87.908)
# epoch = 5, step = 12, lr = 0.008
# Epoch: [5][12/12]  Time 0.147 (0.257)  Speed 3493.032 (1989.021)  Loss 1.4584929943 (1.5635)  Prec@1 54.286 (51.556)  Prec@5 90.357 (88.024)
# epoch = 5, step = 12, lr = 0.008
# Epoch: [5][12/12]  Time 0.147 (0.258)  Speed 3493.072 (1987.430)  Loss 1.4584929943 (1.5635)  Prec@1 54.286 (51.556)  Prec@5 90.357 (88.024)
#   Prec@1 13.649 Prec@5 40.743
#   Prec@1 13.649 Prec@5 40.743
#   Prec@1 13.649 Prec@5 40.743
#   Prec@1 13.649 Prec@5 40.743
#  ****  acc1 :13.648648262023926
#  ****  acc1 :13.648648262023926
#  ****  acc1 :13.648648262023926
#  ****  acc1 :13.648648262023926
# Saving the model.
#   Prec@1 13.649 Prec@5 40.743
#   Prec@1 13.649 Prec@5 40.743
#   Prec@1 13.649 Prec@5 40.743
#   Prec@1 13.649 Prec@5 40.743
#  ****  acc1 :13.648648262023926
#  ****  acc1 :13.648648262023926
#  ****  acc1 :13.648648262023926
#  ****  acc1 :13.648648262023926
# Saving the model.
# epoch = 6, step = 1, lr = 0.008
# epoch = 6, step = 1, lr = 0.008
# Epoch: [6][1/12]  Time 0.785 (0.785)  Speed 652.236 (652.236)  Loss 1.5692785978 (1.5693)  Prec@1 52.930 (52.930)  Prec@5 88.672 (88.672)
# epoch = 6, step = 2, lr = 0.008
# Epoch: [6][1/12]  Time 0.787 (0.787)  Speed 650.230 (650.230)  Loss 1.5692785978 (1.5693)  Prec@1 52.930 (52.930)  Prec@5 88.672 (88.672)
# epoch = 6, step = 2, lr = 0.008
# Epoch: [6][2/12]  Time 0.217 (0.501)  Speed 2363.015 (1022.298)  Loss 1.4841284752 (1.5267)  Prec@1 53.711 (53.320)  Prec@5 88.086 (88.379)
# epoch = 6, step = 3, lr = 0.008
(0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 8, lr = 0.0008
# Epoch: [48][8/12]  Time 0.219 (0.288)  Speed 2338.097 (1777.854)  Loss 0.0030452479 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 9, lr = 0.0008
# Epoch: [48][8/12]  Time 0.219 (0.288)  Speed 2338.134 (1776.528)  Loss 0.0030452479 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 9, lr = 0.0008
# Epoch: [48][9/12]  Time 0.219 (0.280)  Speed 2340.647 (1825.410)  Loss 0.0031444076 (0.0036)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 10, lr = 0.0008
# Epoch: [48][9/12]  Time 0.219 (0.280)  Speed 2340.674 (1826.657)  Loss 0.0031444076 (0.0036)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 10, lr = 0.0008
# Epoch: [48][10/12]  Time 0.218 (0.274)  Speed 2345.083 (1866.778)  Loss 0.0034096446 (0.0036)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 11, lr = 0.0008
# Epoch: [48][10/12]  Time 0.218 (0.274)  Speed 2345.077 (1867.951)  Loss 0.0034096446 (0.0036)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 11, lr = 0.0008
# Epoch: [48][11/12]  Time 0.219 (0.269)  Speed 2341.910 (1901.856)  Loss 0.0024832729 (0.0035)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# Epoch: [48][11/12]  Time 0.219 (0.269)  Speed 2341.870 (1902.960)  Loss 0.0024832729 (0.0035)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 48, step = 12, lr = 0.0008
# epoch = 48, step = 12, lr = 0.0008
# Epoch: [48][12/12]  Time 0.149 (0.259)  Speed 3447.201 (1975.661)  Loss 0.0064612082 (0.0036)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# Epoch: [48][12/12]  Time 0.149 (0.259)  Speed 3447.305 (1976.757)  Loss 0.0064612082 (0.0036)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
#   Prec@1 78.649 Prec@5 96.554
#   Prec@1 78.649 Prec@5 96.554
#   Prec@1 78.649 Prec@5 96.554
#   Prec@1 78.649 Prec@5 96.554
#  ****  acc1 :78.64864349365234
#  ****  acc1 :78.64864349365234
#  ****  acc1 :78.64864349365234
#  ****  acc1 :78.64864349365234
# Saving the model.
#   Prec@1 78.649 Prec@5 96.554
#   Prec@1 78.649 Prec@5 96.554
#   Prec@1 78.649 Prec@5 96.554
#   Prec@1 78.649 Prec@5 96.554
#  ****  acc1 :78.64864349365234
#  ****  acc1 :78.64864349365234
#  ****  acc1 :78.64864349365234
#  ****  acc1 :78.64864349365234
# Saving the model.
# epoch = 49, step = 1, lr = 0.0008
# epoch = 49, step = 1, lr = 0.0008
# Epoch: [49][1/12]  Time 0.798 (0.798)  Speed 641.705 (641.705)  Loss 0.0047154464 (0.0047)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 2, lr = 0.0008
# Epoch: [49][1/12]  Time 0.792 (0.792)  Speed 646.427 (646.427)  Loss 0.0047154464 (0.0047)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 2, lr = 0.0008
# Epoch: [49][2/12]  Time 0.219 (0.509)  Speed 2333.615 (1006.609)  Loss 0.0037830863 (0.0042)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 3, lr = 0.0008
# Epoch: [49][2/12]  Time 0.219 (0.506)  Speed 2333.578 (1012.406)  Loss 0.0037830863 (0.0042)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 3, lr = 0.0008
# Epoch: [49][3/12]  Time 0.218 (0.410)  Speed 2346.177 (1249.106)  Loss 0.0050214194 (0.0045)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 4, lr = 0.0008
# Epoch: [49][4/12]  Time 0.217 (0.362)  Speed 2354.900 (1415.246)  Loss 0.0036537647 (0.0043)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 5, lr = 0.0008
# Epoch: [49][3/12]  Time 0.218 (0.412)  Speed 2346.195 (1243.219)  Loss 0.0050214194 (0.0045)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 4, lr = 0.0008
# Epoch: [49][4/12]  Time 0.217 (0.363)  Speed 2354.859 (1409.570)  Loss 0.0036537647 (0.0043)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 5, lr = 0.0008
# Epoch: [49][5/12]  Time 0.219 (0.333)  Speed 2340.728 (1536.768)  Loss 0.0029473510 (0.0040)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 6, lr = 0.0008
# Epoch: [49][5/12]  Time 0.219 (0.334)  Speed 2340.722 (1531.411)  Loss 0.0029473510 (0.0040)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 6, lr = 0.0008
# Epoch: [49][6/12]  Time 0.219 (0.314)  Speed 2334.347 (1629.564)  Loss 0.0024319123 (0.0038)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 7, lr = 0.0008
# Epoch: [49][6/12]  Time 0.219 (0.315)  Speed 2334.349 (1624.542)  Loss 0.0024319123 (0.0038)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 7, lr = 0.0008
# Epoch: [49][7/12]  Time 0.219 (0.301)  Speed 2335.341 (1698.390)  Loss 0.0031970758 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 8, lr = 0.0008
# Epoch: [49][7/12]  Time 0.219 (0.301)  Speed 2335.324 (1703.092)  Loss 0.0031970758 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 8, lr = 0.0008
# Epoch: [49][8/12]  Time 0.218 (0.291)  Speed 2343.456 (1758.910)  Loss 0.0038909726 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 9, lr = 0.0008
# Epoch: [49][8/12]  Time 0.218 (0.290)  Speed 2343.446 (1763.321)  Loss 0.0038909726 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 9, lr = 0.0008
# Epoch: [49][9/12]  Time 0.219 (0.283)  Speed 2333.422 (1808.381)  Loss 0.0037756171 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 10, lr = 0.0008
# Epoch: [49][9/12]  Time 0.219 (0.282)  Speed 2334.057 (1812.567)  Loss 0.0037756171 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 10, lr = 0.0008
# Epoch: [49][10/12]  Time 0.219 (0.276)  Speed 2342.741 (1854.536)  Loss 0.0041615404 (0.0038)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 11, lr = 0.0008
# Epoch: [49][10/12]  Time 0.218 (0.277)  Speed 2343.364 (1850.631)  Loss 0.0041615404 (0.0038)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 11, lr = 0.0008
# Epoch: [49][11/12]  Time 0.219 (0.271)  Speed 2340.268 (1890.202)  Loss 0.0030499753 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# Epoch: [49][11/12]  Time 0.219 (0.271)  Speed 2340.285 (1886.514)  Loss 0.0030499753 (0.0037)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 49, step = 12, lr = 0.0008
# epoch = 49, step = 12, lr = 0.0008
# Epoch: [49][12/12]  Time 0.150 (0.261)  Speed 3417.865 (1959.682)  Loss 0.0064194780 (0.0038)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# Epoch: [49][12/12]  Time 0.150 (0.261)  Speed 3417.812 (1963.328)  Loss 0.0064194780 (0.0038)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
#   Prec@1 78.851 Prec@5 96.486
#   Prec@1 78.851 Prec@5 96.486
#   Prec@1 78.851 Prec@5 96.486
#   Prec@1 78.851 Prec@5 96.486
#  ****  acc1 :78.85134887695312
#  ****  acc1 :78.85134887695312
#  ****  acc1 :78.85134887695312
#  ****  acc1 :78.85134887695312
# Saving the model.
#   Prec@1 78.851 Prec@5 96.486
#   Prec@1 78.851 Prec@5 96.486
#   Prec@1 78.851 Prec@5 96.486
#   Prec@1 78.851 Prec@5 96.486
#  ****  acc1 :78.85134887695312
#  ****  acc1 :78.85134887695312
#  ****  acc1 :78.85134887695312
#  ****  acc1 :78.85134887695312
# Saving the model.
# epoch = 50, step = 1, lr = 0.0008
# epoch = 50, step = 1, lr = 0.0008
# Epoch: [50][1/12]  Time 0.797 (0.797)  Speed 642.186 (642.186)  Loss 0.0048401784 (0.0048)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 2, lr = 0.0008
# Epoch: [50][1/12]  Time 0.804 (0.804)  Speed 636.581 (636.581)  Loss 0.0048401784 (0.0048)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 2, lr = 0.0008
# Epoch: [50][2/12]  Time 0.217 (0.507)  Speed 2363.906 (1009.995)  Loss 0.0030659493 (0.0040)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 3, lr = 0.0008
# Epoch: [50][2/12]  Time 0.217 (0.510)  Speed 2363.809 (1003.041)  Loss 0.0030659493 (0.0040)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 3, lr = 0.0008
# Epoch: [50][3/12]  Time 0.216 (0.412)  Speed 2366.108 (1241.428)  Loss 0.0024029389 (0.0034)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 4, lr = 0.0008
# Epoch: [50][4/12]  Time 0.219 (0.364)  Speed 2334.280 (1405.990)  Loss 0.0032072626 (0.0034)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 5, lr = 0.0008
# Epoch: [50][3/12]  Time 0.216 (0.410)  Speed 2366.074 (1248.517)  Loss 0.0024029389 (0.0034)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 4, lr = 0.0008
# Epoch: [50][4/12]  Time 0.219 (0.362)  Speed 2334.285 (1412.805)  Loss 0.0032072626 (0.0034)  Prec@1 100.000 (100.000)  Prec@5 100.000 (100.000)
# epoch = 50, step = 5, lr = 0.0008
# Epoch: [50][5/12]  Time 0.218 (0.334)  Speed 2347.687 (1535.062)  Loss 0.0072123241 (0.0041)  Prec@1 99.805 (99.961)  Prec@5 100.000 (100.000)
# epoch = 50, step = 6, lr = 0.0008
# Epoch: [50][5/12]  Time 0.218 (0.335)  Speed 2347.779 (1528.629)  Loss 0.0072123241 (0.0041)  Prec@1 99.805 (99.961)  Prec@5 100.000 (100.000)
# epoch = 50, step = 6, lr = 0.0008
# Epoch: [50][6/12]  Time 0.219 (0.314)  Speed 2338.859 (1628.330)  Loss 0.0025165603 (0.0039)  Prec@1 100.000 (99.967)  Prec@5 100.000 (100.000)
# epoch = 50, step = 7, lr = 0.0008
# Epoch: [50][6/12]  Time 0.219 (0.316)  Speed 2338.742 (1622.286)  Loss 0.0025165603 (0.0039)  Prec@1 100.000 (99.967)  Prec@5 100.000 (100.000)
# epoch = 50, step = 7, lr = 0.0008
# Epoch: [50][7/12]  Time 0.218 (0.301)  Speed 2343.970 (1702.590)  Loss 0.0017586183 (0.0036)  Prec@1 100.000 (99.972)  Prec@5 100.000 (100.000)
# epoch = 50, step = 8, lr = 0.0008
# Epoch: [50][7/12]  Time 0.218 (0.302)  Speed 2343.967 (1696.924)  Loss 0.0017586183 (0.0036)  Prec@1 100.000 (99.972)  Prec@5 100.000 (100.000)
# epoch = 50, step = 8, lr = 0.0008
# Epoch: [50][8/12]  Time 0.218 (0.291)  Speed 2351.876 (1758.124)  Loss 0.0048805401 (0.0037)  Prec@1 100.000 (99.976)  Prec@5 100.000 (100.000)
# epoch = 50, step = 9, lr = 0.0008
# Epoch: [50][8/12]  Time 0.218 (0.290)  Speed 2351.841 (1763.442)  Loss 0.0048805401 (0.0037)  Prec@1 100.000 (99.976)  Prec@5 100.000 (100.000)
# epoch = 50, step = 9, lr = 0.0008
# Epoch: [50][9/12]  Time 0.218 (0.283)  Speed 2345.404 (1808.438)  Loss 0.0043569710 (0.0038)  Prec@1 100.000 (99.978)  Prec@5 100.000 (100.000)
# epoch = 50, step = 10, lr = 0.0008
# Epoch: [50][9/12]  Time 0.218 (0.282)  Speed 2345.396 (1813.438)  Loss 0.0043569710 (0.0038)  Prec@1 100.000 (99.978)  Prec@5 100.000 (100.000)
# epoch = 50, step = 10, lr = 0.0008
# Epoch: [50][10/12]  Time 0.220 (0.277)  Speed 2328.669 (1849.762)  Loss 0.0026785936 (0.0037)  Prec@1 100.000 (99.980)  Prec@5 100.000 (100.000)
# epoch = 50, step = 11, lr = 0.0008
# Epoch: [50][10/12]  Time 0.220 (0.276)  Speed 2328.689 (1854.470)  Loss 0.0026785936 (0.0037)  Prec@1 100.000 (99.980)  Prec@5 100.000 (100.000)
# epoch = 50, step = 11, lr = 0.0008
# Epoch: [50][11/12]  Time 0.220 (0.271)  Speed 2327.338 (1889.369)  Loss 0.0028243065 (0.0036)  Prec@1 100.000 (99.982)  Prec@5 100.000 (100.000)
# epoch = 50, step = 12, lr = 0.0008
# Epoch: [50][11/12]  Time 0.220 (0.272)  Speed 2327.336 (1884.925)  Loss 0.0028243065 (0.0036)  Prec@1 100.000 (99.982)  Prec@5 100.000 (100.000)
# epoch = 50, step = 12, lr = 0.0008
# Epoch: [50][12/12]  Time 0.149 (0.261)  Speed 3425.978 (1958.332)  Loss 0.0140307862 (0.0041)  Prec@1 99.286 (99.949)  Prec@5 100.000 (100.000)
# Epoch: [50][12/12]  Time 0.149 (0.261)  Speed 3426.002 (1962.729)  Loss 0.0140307862 (0.0041)  Prec@1 99.286 (99.949)  Prec@5 100.000 (100.000)
# 2020-07-23 00:31:53 Uploading - Uploading generated training model  Prec@1 79.122 Prec@5 96.216
#   Prec@1 79.122 Prec@5 96.216
#   Prec@1 79.122 Prec@5 96.216
#   Prec@1 79.122 Prec@5 96.216
#  ****  acc1 :79.12161254882812
#  ****  acc1 :79.12161254882812
#  ****  acc1 :79.12161254882812
#  ****  acc1 :79.12161254882812
# [2020-07-23 00:31:48.523 algo-1:107 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [2020-07-23 00:31:48.523 algo-1:106 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [2020-07-23 00:31:48.523 algo-1:108 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# Saving the model.
#   Prec@1 79.122 Prec@5 96.216
#   Prec@1 79.122 Prec@5 96.216
#   Prec@1 79.122 Prec@5 96.216
#   Prec@1 79.122 Prec@5 96.216
#  ****  acc1 :79.12161254882812
#  ****  acc1 :79.12161254882812
#  ****  acc1 :79.12161254882812
#  ****  acc1 :79.12161254882812
# [2020-07-23 00:31:48.522 algo-2:106 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [2020-07-23 00:31:48.522 algo-2:108 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [2020-07-23 00:31:48.523 algo-2:107 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# Saving the model.
# [2020-07-23 00:31:49.741 algo-1:105 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# [2020-07-23 00:31:49.725 algo-2:105 INFO utils.py:25] The end of training job file will not be written for jobs running under SageMaker.
# 2020-07-23 00:31:50,415 sagemaker-containers INFO     Reporting training SUCCESS
# 2020-07-23 00:31:50,429 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-07-23 00:37:03 Completed - Training job completed
# Training seconds: 4820
# Billable seconds: 4820

# %% [markdown]
# <p>학습이 모두 완료된 다음에 S3에서 모델 산출물을 SageMaker Notebook 환경으로 내려받습니다.</p>

# %%
artifacts_dir = estimator.model_data.replace('model.tar.gz', '')
print(artifacts_dir)
# !aws s3 ls --human-readable {artifacts_dir}
# Out:
# s3://sagemaker-us-east-2-322537213286/training-job-1595462057/output/
# 2020-07-23 00:36:45    2.8 GiB model.tar.gz
# 2020-07-23 00:36:56   15.8 KiB output.tar.gz

# %%
model_dir = './model'
output_dir = './output'

# %%
# !rm -rf $model_dir
# !rm -rf $output_dir

# %%
import json , os

if not os.path.exists(model_dir):
    os.makedirs(model_dir)

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
# !aws s3 cp {artifacts_dir}model.tar.gz {model_dir}/model.tar.gz
# !tar -xzf {model_dir}/model.tar.gz -C {model_dir}
# !aws s3 cp {artifacts_dir}output.tar.gz {output_dir}/output.tar.gz
# !tar -xzf {output_dir}/output.tar.gz -C {output_dir}
# Out:
# download: s3://sagemaker-us-east-2-322537213286/training-job-1595462057/output/model.tar.gz to model/model.tar.gz
# download: s3://sagemaker-us-east-2-322537213286/training-job-1595462057/output/output.tar.gz to output/output.tar.gz

# %% [markdown]
# ## 9. 결과 확인

# %%
import json , os

with open(os.path.join(output_dir, 'model_history.p'), "r") as f:
    model_history = json.load(f)

# %%
import matplotlib.pyplot as plt

def plot_training_curves(history): 
    
    fig, axes = plt.subplots(1, 4, figsize=(18, 4), sharex=True)
    
    ax = axes[0]
    ax.plot(history['epoch'], history['losses'], label='train')
    ax.plot(history['val_avg_epoch'], history['val_avg_losses'], label='validation')
    ax.set(
        title='model loss',
        ylabel='loss',
        xlabel='epoch')
    ax.legend()
    
    ax = axes[1]
    ax.plot(history['epoch'], history['batch_time'], label='train')
    ax.plot(history['val_avg_epoch'], history['val_avg_batch_time'], label='validation')
    ax.set(
        title='model batch_time',
        ylabel='batch_time',
        xlabel='epoch')
    ax.legend()
    
    
    ax = axes[2]
    ax.plot(history['epoch'], history['top1'], label='train')
    ax.plot(history['val_avg_epoch'], history['val_avg_top1'], label='validation')
    ax.set(
        title='top1 accuracy',
        ylabel='accuracy',
        xlabel='epoch')
    ax.legend()
    
    ax = axes[3]
    ax.plot(history['epoch'], history['top5'], label='train')
    ax.plot(history['val_avg_epoch'], history['val_avg_top5'], label='validation')
    ax.set(
        title='top5 accuracy',
        ylabel='accuracy',
        xlabel='epoch')
    ax.legend()
    fig.tight_layout()
    
plot_training_curves(model_history)

# %%
# %store hyperparameters model_dir output_dir artifacts_dir
# Out:
# Stored 'hyperparameters' (dict)
# Stored 'model_dir' (str)
# Stored 'output_dir' (str)
# Stored 'artifacts_dir' (str)

# %% [markdown]
# <p></p>
# <p>Amazon SageMaker에서 모든 학습을 완료하였습니다. </p>
